# %%
import jieba
import csv
import wordcloud
import matplotlib.pyplot as plt

# %%
with open('lfq_csv.csv','r',encoding='utf-8') as f:
    reader=csv.reader(f)
    content=[row[1]for row in reader][1:]

# %%
len(content)
# Out:
# 71

# %%
content
# Out:
# ['复习期末的这几天，我从钻五到了钻一。 \xa0',
#  '转发理由:恭喜@-席瑾- 1名用户获得【1k】。微博官方唯一抽奖工具@微博抽奖平台 对本次抽奖进行监督，结果公正有效。公示链接：微博抽奖平台 //@_老番茄_:庆祝吃鸡，转发抽1k！明天20点开奖！ 查看图片\xa0\xa0',
#  '转发理由:庆祝吃鸡，转发抽1k！明天20点开奖！ 查看图片\xa0\xa0',
#  '又到了一年两度，万众期待的考前临时抱佛脚时间 \xa0',
#  '默契挑战！看看我和BOY谁才是真正的好兄弟#YSL212#  _老番茄_的微博视频 \xa0',
#  '生日快乐，我的偶像 _老番茄_的微博视频 \xa0',
#  '儿童节快乐！希望我的脸能变回小时候那么圆润！ \xa0原图\xa0',
#  '失去梦想变成大鸡腿 \xa0原图\xa0',
#  '决定利用每天上课开小差的时间学一点蒙语。如果下次回内蒙能看懂蒙文了，说明我这学期一定开了很多小差。 \xa0原图\xa0',
#  '为什么b站在我要交作业之前上线柯南剧场版。可恶，已经看了一天柯南了。 \xa0',
#  '昨晚失眠睡不着，翻来覆去。四点钟的时候，突然悟到，好像是热得睡不着。于是毅然打开了空调，立马睡着了。 \xa0',
#  '转发理由:给我的好弟弟打call 查看图片 //@最强大脑陆英泽:#最强大脑开播##最强大脑#还有半小时就要开播拉，看不了电视的也可以访问http://t.cn/heFOA收看网络直播\xa0\xa0',
#  '完美还原世界名画！你说我画挑战。天猫搜索OPPO官方旗舰店get同款耳机  _老番茄_的微博视频 \xa0',
#  '藏在黑影中的小怪兽 _老番茄_的微博视频 \xa0',
#  '感谢@腾讯NintendoSwitch 送的国行switch和李维斯联名小夹克儿！耀西真可爱 \xa0[组图共3张]\xa0原图\xa0',
#  '打算做视频之前休息一会→看一眼直播→看到有人在玩奥特曼游戏→勾起回忆→看了一整晚的奥特曼 \xa0',
#  '如何让脸看上去不那么长：强行遮住下巴 \xa0原图\xa0',
#  '分享图片 \xa0原图\xa0',
#  '第一次网课考试，真是有趣的体验。每当抓耳挠腮做不出来的时候，切到会议室，发现同学们也在抓耳挠腮，我就放心了。 \xa0',
#  '还有一天就考试了！开启临时抱佛脚模式！ \xa0',
#  '#世界读书日# 推荐一下《围城》吧，特有意思。高中看的，大学时出门还经常揣着在飞机上重温（虽然最后都睡着了） \xa0',
#  '“猫” \xa0原图\xa0',
#  '最近不知道为啥，总感觉提不起劲，很累，明明也没有很忙。是不是我的内心太想返校上学了。 \xa0',
#  '走到半路下暴雨了，现在是一只瑟瑟发抖的落汤鸡 \xa0',
#  '下课了。明天早上还要起来上课。头发渐渐消失。 \xa0',
#  '他感动的快要哭了。 _老番茄_的微博视频 \xa0',
#  '转发理由:致敬，缅怀。\xa0\xa0',
#  '总算做完视频和封面了，但是明天还有早课和作业🙉🙉🙉头发要掉光了！ \xa0原图\xa0',
#  '不知道为什么，看到这只就想笑 \xa0原图\xa0',
#  '这周有个四个作业要交（还没开始），如果活过这周，我一定好好做视频 \xa0',
#  '我也开始了 \xa0原图\xa0',
#  '最近外卖点太多了。外卖小哥对我的称呼已经从“张先生”变成了“张哥”，现在是“小张”了。 \xa0',
#  '最近天天失眠，所以今天决定睡前做点作业，帮助自己尽快入眠 \xa0',
#  '晚睡→艰难早起上课→补觉到傍晚→晕乎乎地摸鱼→因为补了觉睡不着→晚睡。 \xa0原图\xa0',
#  '小狗为何愁容满面 \xa0原图\xa0',
#  '谁能想到，正式开始上网课前一天晚上，我通宵玩了一晚上扫雷。 \xa0',
#  '宅在家有什么能拍的生活区视频吗，想不出来！ \xa0',
#  '理完发了，终于重见光明了。 \xa0原图\xa0',
#  '我被黑猫警长抓捕了 \xa0原图\xa0',
#  '涂润唇膏的时候吃了一口，真难吃，我再也不吃润唇膏了。 \xa0',
#  '明天要开始上网课了，有缘再见 \xa0',
#  '不小心买多了，不得不天天啃草，一天啃两顿草 _老番茄_的微博视频 \xa0',
#  '人类的本质 \xa0[组图共2张]\xa0原图\xa0',
#  '很懒，但又要保证膳食均衡，于是买了一冰箱的黄瓜，现在没事就啃黄瓜，快变成黄瓜人了。 \xa0',
#  '年前忘了去理发的我，现在已经得夹发卡才看得见东西了 \xa0',
#  '真没想到我竟然更新了，真不赖 \xa0',
#  '好闲啊。 \xa0原图\xa0',
#  '转发理由:新年快乐！多夸夸自己！\xa0\xa0',
#  '退烧了。新年快乐，一切顺意！最重要的是身体健康！ \xa0',
#  '分享图片 \xa0原图\xa0',
#  '从百大回来就一直在发烧，怕传染给别人所以一直把自己关在家里。原定要在春节发的视频做不出来了，非常对不起期待我更新的观众们。好在血氧一直维持在96-97，也没有出现呼吸困难。大家要好好注意身体呀，我继续去瘫着了。 \xa0',
#  '转发理由:我我我，我。。//@复旦大学:让我康康到底是谁家的排面//@上海财经大学:财大排面！老番茄冲！//@哔哩哔哩智能姬:#B站百大UP主#揭晓！快来看看都有谁~~来为喜欢的UP主加油呀！\xa0\xa0',
#  '转发理由:🙊懵了！谢谢财大！//@上海财经大学:财大排面！老番茄冲！//@哔哩哔哩智能姬:#B站百大UP主#揭晓！快来看看都有谁~~来为喜欢的UP主加油呀！\xa0\xa0',
#  '谢谢大家，我太紧张了 \xa0原图\xa0',
#  '哈哈哈哈百大的照片拍的像食人魔 \xa0原图\xa0',
#  '为期两天的寒假小学期结束了！我又放假了！ \xa0原图\xa0',
#  '我又开学啦，哈哈哈哈 \xa0原图\xa0',
#  '我和沼王烛光晚餐🕯🕯 \xa0原图\xa0',
#  '马上最后一门了大家期末加油，我玩会手机。 \xa0',
#  '今天去拍照，我问发型师，我是不是发际线高。她说，不高不高，因为你脸很长，才显得高。我一时不知道是该笑该哭。 \xa0',
#  '已经好久没在理发店听到“小伙头发挺厚”的夸奖了 \xa0原图\xa0',
#  '看了看年度总结。为什么最多的弹幕是泪目啊哈哈哈哈哈哈哈 \xa0[组图共3张]\xa0原图\xa0',
#  '2020，我来啦！！ \xa0[组图共4张]\xa0原图\xa0',
#  '又到了每学期期末的焦虑时间 \xa0',
#  '给茄酱找了个男朋友 \xa0原图\xa0',
#  '经过一学期的学习，我的编程水平如图。 \xa0原图\xa0',
#  '考研加油！吃好睡好！ \xa0原图\xa0',
#  '冷冷的冰雨在茄上胡乱的拍 \xa0原图\xa0',
#  '得了一下雨就不想上学的怪病 \xa0原图\xa0',
#  '这个狗仿佛在喂奶。 \xa0原图\xa0',
#  '奇怪，明明什么都没记住一学期就过去了 \xa0原图\xa0']

# %%
stopwords_list = [k.strip() for k in open('stopwords.txt', encoding='utf8').readlines() if k.strip() != '\n']

# %%
len(stopwords_list)
# Out:
# 1893

# %%
def stopwords_append(s,stopwords_list):
    if s not in stopwords_list:
        stopwords_list.append(s)

# %%
stopwords_append('置顶',stopwords_list)
stopwords_append('转发理由',stopwords_list)
stopwords_append('转发',stopwords_list)
stopwords_append('理由',stopwords_list)
stopwords_append('明星动态',stopwords_list)
stopwords_append('微博视频',stopwords_list)
stopwords_append('原图',stopwords_list)
stopwords_append('易',stopwords_list)
stopwords_append('烊',stopwords_list)
stopwords_append('千玺',stopwords_list)
stopwords_append(' ',stopwords_list)
stopwords_append('\xa0',stopwords_list)
stopwords_append('组图',stopwords_list)
stopwords_append('张',stopwords_list)
stopwords_append('',stopwords_list)
stopwords_append('视频',stopwords_list)
stopwords_append('http',stopwords_list)
stopwords_append('cn',stopwords_list)
stopwords_append('微博',stopwords_list)
stopwords_append('番茄',stopwords_list)
stopwords_append('图片',stopwords_list)

# %%
txt=' '.join(content)

# %%
txt
# Out:
# '复习期末的这几天，我从钻五到了钻一。 \xa0 转发理由:恭喜@-席瑾- 1名用户获得【1k】。微博官方唯一抽奖工具@微博抽奖平台 对本次抽奖进行监督，结果公正有效。公示链接：微博抽奖平台 //@_老番茄_:庆祝吃鸡，转发抽1k！明天20点开奖！ 查看图片\xa0\xa0 转发理由:庆祝吃鸡，转发抽1k！明天20点开奖！ 查看图片\xa0\xa0 又到了一年两度，万众期待的考前临时抱佛脚时间 \xa0 默契挑战！看看我和BOY谁才是真正的好兄弟#YSL212#  _老番茄_的微博视频 \xa0 生日快乐，我的偶像 _老番茄_的微博视频 \xa0 儿童节快乐！希望我的脸能变回小时候那么圆润！ \xa0原图\xa0 失去梦想变成大鸡腿 \xa0原图\xa0 决定利用每天上课开小差的时间学一点蒙语。如果下次回内蒙能看懂蒙文了，说明我这学期一定开了很多小差。 \xa0原图\xa0 为什么b站在我要交作业之前上线柯南剧场版。可恶，已经看了一天柯南了。 \xa0 昨晚失眠睡不着，翻来覆去。四点钟的时候，突然悟到，好像是热得睡不着。于是毅然打开了空调，立马睡着了。 \xa0 转发理由:给我的好弟弟打call 查看图片 //@最强大脑陆英泽:#最强大脑开播##最强大脑#还有半小时就要开播拉，看不了电视的也可以访问http://t.cn/heFOA收看网络直播\xa0\xa0 完美还原世界名画！你说我画挑战。天猫搜索OPPO官方旗舰店get同款耳机  _老番茄_的微博视频 \xa0 藏在黑影中的小怪兽 _老番茄_的微博视频 \xa0 感谢@腾讯NintendoSwitch 送的国行switch和李维斯联名小夹克儿！耀西真可爱 \xa0[组图共3张]\xa0原图\xa0 打算做视频之前休息一会→看一眼直播→看到有人在玩奥特曼游戏→勾起回忆→看了一整晚的奥特曼 \xa0 如何让脸看上去不那么长：强行遮住下巴 \xa0原图\xa0 分享图片 \xa0原图\xa0 第一次网课考试，真是有趣的体验。每当抓耳挠腮做不出来的时候，切到会议室，发现同学们也在抓耳挠腮，我就放心了。 \xa0 还有一天就考试了！开启临时抱佛脚模式！ \xa0 #世界读书日# 推荐一下《围城》吧，特有意思。高中看的，大学时出门还经常揣着在飞机上重温（虽然最后都睡着了） \xa0 “猫” \xa0原图\xa0 最近不知道为啥，总感觉提不起劲，很累，明明也没有很忙。是不是我的内心太想返校上学了。 \xa0 走到半路下暴雨了，现在是一只瑟瑟发抖的落汤鸡 \xa0 下课了。明天早上还要起来上课。头发渐渐消失。 \xa0 他感动的快要哭了。 _老番茄_的微博视频 \xa0 转发理由:致敬，缅怀。\xa0\xa0 总算做完视频和封面了，但是明天还有早课和作业🙉🙉🙉头发要掉光了！ \xa0原图\xa0 不知道为什么，看到这只就想笑 \xa0原图\xa0 这周有个四个作业要交（还没开始），如果活过这周，我一定好好做视频 \xa0 我也开始了 \xa0原图\xa0 最近外卖点太多了。外卖小哥对我的称呼已经从“张先生”变成了“张哥”，现在是“小张”了。 \xa0 最近天天失眠，所以今天决定睡前做点作业，帮助自己尽快入眠 \xa0 晚睡→艰难早起上课→补觉到傍晚→晕乎乎地摸鱼→因为补了觉睡不着→晚睡。 \xa0原图\xa0 小狗为何愁容满面 \xa0原图\xa0 谁能想到，正式开始上网课前一天晚上，我通宵玩了一晚上扫雷。 \xa0 宅在家有什么能拍的生活区视频吗，想不出来！ \xa0 理完发了，终于重见光明了。 \xa0原图\xa0 我被黑猫警长抓捕了 \xa0原图\xa0 涂润唇膏的时候吃了一口，真难吃，我再也不吃润唇膏了。 \xa0 明天要开始上网课了，有缘再见 \xa0 不小心买多了，不得不天天啃草，一天啃两顿草 _老番茄_的微博视频 \xa0 人类的本质 \xa0[组图共2张]\xa0原图\xa0 很懒，但又要保证膳食均衡，于是买了一冰箱的黄瓜，现在没事就啃黄瓜，快变成黄瓜人了。 \xa0 年前忘了去理发的我，现在已经得夹发卡才看得见东西了 \xa0 真没想到我竟然更新了，真不赖 \xa0 好闲啊。 \xa0原图\xa0 转发理由:新年快乐！多夸夸自己！\xa0\xa0 退烧了。新年快乐，一切顺意！最重要的是身体健康！ \xa0 分享图片 \xa0原图\xa0 从百大回来就一直在发烧，怕传染给别人所以一直把自己关在家里。原定要在春节发的视频做不出来了，非常对不起期待我更新的观众们。好在血氧一直维持在96-97，也没有出现呼吸困难。大家要好好注意身体呀，我继续去瘫着了。 \xa0 转发理由:我我我，我。。//@复旦大学:让我康康到底是谁家的排面//@上海财经大学:财大排面！老番茄冲！//@哔哩哔哩智能姬:#B站百大UP主#揭晓！快来看看都有谁~~来为喜欢的UP主加油呀！\xa0\xa0 转发理由:🙊懵了！谢谢财大！//@上海财经大学:财大排面！老番茄冲！//@哔哩哔哩智能姬:#B站百大UP主#揭晓！快来看看都有谁~~来为喜欢的UP主加油呀！\xa0\xa0 谢谢大家，我太紧张了 \xa0原图\xa0 哈哈哈哈百大的照片拍的像食人魔 \xa0原图\xa0 为期两天的寒假小学期结束了！我又放假了！ \xa0原图\xa0 我又开学啦，哈哈哈哈 \xa0原图\xa0 我和沼王烛光晚餐🕯🕯 \xa0原图\xa0 马上最后一门了大家期末加油，我玩会手机。 \xa0 今天去拍照，我问发型师，我是不是发际线高。她说，不高不高，因为你脸很长，才显得高。我一时不知道是该笑该哭。 \xa0 已经好久没在理发店听到“小伙头发挺厚”的夸奖了 \xa0原图\xa0 看了看年度总结。为什么最多的弹幕是泪目啊哈哈哈哈哈哈哈 \xa0[组图共3张]\xa0原图\xa0 2020，我来啦！！ \xa0[组图共4张]\xa0原图\xa0 又到了每学期期末的焦虑时间 \xa0 给茄酱找了个男朋友 \xa0原图\xa0 经过一学期的学习，我的编程水平如图。 \xa0原图\xa0 考研加油！吃好睡好！ \xa0原图\xa0 冷冷的冰雨在茄上胡乱的拍 \xa0原图\xa0 得了一下雨就不想上学的怪病 \xa0原图\xa0 这个狗仿佛在喂奶。 \xa0原图\xa0 奇怪，明明什么都没记住一学期就过去了 \xa0原图\xa0'

# %%
word_list=jieba.lcut(txt)

# %%
word_list
# Out:
# ['复习',
#  '期末',
#  '的',
#  '这',
#  '几天',
#  '，',
#  '我',
#  '从',
#  '钻五到',
#  '了',
#  '钻',
#  '一',
#  '。',
#  ' ',
#  '\xa0',
#  ' ',
#  '转发',
#  '理由',
#  ':',
#  '恭喜',
#  '@',
#  '-',
#  '席瑾',
#  '-',
#  ' ',
#  '1',
#  '名',
#  '用户',
#  '获得',
#  '【',
#  '1k',
#  '】',
#  '。',
#  '微博',
#  '官方',
#  '唯一',
#  '抽奖',
#  '工具',
#  '@',
#  '微博',
#  '抽奖',
#  '平台',
#  ' ',
#  '对',
#  '本次',
#  '抽奖',
#  '进行',
#  '监督',
#  '，',
#  '结果',
#  '公正',
#  '有效',
#  '。',
#  '公示',
#  '链接',
#  '：',
#  '微博',
#  '抽奖',
#  '平台',
#  ' ',
#  '/',
#  '/',
#  '@',
#  '_',
#  '老',
#  '番茄',
#  '_',
#  ':',
#  '庆祝',
#  '吃',
#  '鸡',
#  '，',
#  '转发',
#  '抽',
#  '1k',
#  '！',
#  '明天',
#  '20',
#  '点',
#  '开奖',
#  '！',
#  ' ',
#  '查看',
#  '图片',
#  '\xa0',
#  '\xa0',
#  ' ',
#  '转发',
#  '理由',
#  ':',
#  '庆祝',
#  '吃',
#  '鸡',
#  '，',
#  '转发',
#  '抽',
#  '1k',
#  '！',
#  '明天',
#  '20',
#  '点',
#  '开奖',
#  '！',
#  ' ',
#  '查看',
#  '图片',
#  '\xa0',
#  '\xa0',
#  ' ',
#  '又',
#  '到',
#  '了',
#  '一年',
#  '两度',
#  '，',
#  '万众',
#  '期待',
#  '的',
#  '考前',
#  '临时',
#  '抱佛脚',
#  '时间',
#  ' ',
#  '\xa0',
#  ' ',
#  '默契',
#  '挑战',
#  '！',
#  '看看',
#  '我',
#  '和',
#  'BOY',
#  '谁',
#  '才',
#  '是',
#  '真正',
#  '的',
#  '好',
#  '兄弟',
#  '#',
#  'YSL212',
#  '#',
#  ' ',
#  ' ',
#  '_',
#  '老',
#  '番茄',
#  '_',
#  '的',
#  '微博',
#  '视频',
#  ' ',
#  '\xa0',
#  ' ',
#  '生日快乐',
#  '，',
#  '我',
#  '的',
#  '偶像',
#  ' ',
#  '_',
#  '老',
#  '番茄',
#  '_',
#  '的',
#  '微博',
#  '视频',
#  ' ',
#  '\xa0',
#  ' ',
#  '儿童节',
#  '快乐',
#  '！',
#  '希望',
#  '我',
#  '的',
#  '脸能',
#  '变回',
#  '小时候',
#  '那么',
#  '圆润',
#  '！',
#  ' ',
#  '\xa0',
#  '原图',
#  '\xa0',
#  ' ',
#  '失去',
#  '梦想',
#  '变成',
#  '大',
#  '鸡腿',
#  ' ',
#  '\xa0',
#  '原图',
#  '\xa0',
#  ' ',
#  '决定',
#  '利用',
#  '每天',
#  '上课',
#  '开小差',
#  '的',
#  '时间',
#  '学',
#  '一点',
#  '蒙语',
#  '。',
#  '如果',
#  '下次',
#  '回',
#  '内蒙',
#  '能看懂',
#  '蒙文',
#  '了',
#  '，',
#  '说明',
#  '我',
#  '这',
#  '学期',
#  '一定',
#  '开',
#  '了',
#  '很多',
#  '小差',
#  '。',
#  ' ',
#  '\xa0',
#  '原图',
#  '\xa0',
#  ' ',
#  '为什么',
#  'b',
#  '站',
#  '在',
#  '我',
#  '要',
#  '交',
#  '作业',
#  '之前',
#  '上线',
#  '柯南',
#  '剧场版',
#  '。',
#  '可恶',
#  '，',
#  '已经',
#  '看',
#  '了',
#  '一天',
#  '柯南',
#  '了',
#  '。',
#  ' ',
#  '\xa0',
#  ' ',
#  '昨晚',
#  '失眠',
#  '睡不着',
#  '，',
#  '翻来覆去',
#  '。',
#  '四点',
#  '钟',
#  '的',
#  '时候',
#  '，',
#  '突然',
#  '悟',
#  '到',
#  '，',
#  '好像',
#  '是',
#  '热得',
#  '睡不着',
#  '。',
#  '于是',
#  '毅然',
#  '打开',
#  '了',
#  '空调',
#  '，',
#  '立马',
#  '睡着',
#  '了',
#  '。',
#  ' ',
#  '\xa0',
#  ' ',
#  '转发',
#  '理由',
#  ':',
#  '给',
#  '我',
#  '的',
#  '好',
#  '弟弟',
#  '打',
#  'call',
#  ' ',
#  '查看',
#  '图片',
#  ' ',
#  '/',
#  '/',
#  '@',
#  '最强',
#  '大脑',
#  '陆英泽',
#  ':',
#  '#',
#  '最强',
#  '大脑',
#  '开播',
#  '##',
#  '最强',
#  '大脑',
#  '#',
#  '还有',
#  '半小时',
#  '就要',
#  '开播',
#  '拉',
#  '，',
#  '看',
#  '不了',
#  '电视',
#  '的',
#  '也',
#  '可以',
#  '访问',
#  'http',
#  ':',
#  '/',
#  '/',
#  't',
#  '.',
#  'cn',
#  '/',
#  'heFOA',
#  '收看',
#  '网络',
#  '直播',
#  '\xa0',
#  '\xa0',
#  ' ',
#  '完美',
#  '还原',
#  '世界',
#  '名画',
#  '！',
#  '你',
#  '说',
#  '我',
#  '画',
#  '挑战',
#  '。',
#  '天猫',
#  '搜索',
#  'OPPO',
#  '官方',
#  '旗舰店',
#  'get',
#  '同款',
#  '耳机',
#  ' ',
#  ' ',
#  '_',
#  '老',
#  '番茄',
#  '_',
#  '的',
#  '微博',
#  '视频',
#  ' ',
#  '\xa0',
#  ' ',
#  '藏',
#  '在',
#  '黑影',
#  '中',
#  '的',
#  '小',
#  '怪兽',
#  ' ',
#  '_',
#  '老',
#  '番茄',
#  '_',
#  '的',
#  '微博',
#  '视频',
#  ' ',
#  '\xa0',
#  ' ',
#  '感谢',
#  '@',
#  '腾讯',
#  'NintendoSwitch',
#  ' ',
#  '送',
#  '的',
#  '国行',
#  'switch',
#  '和',
#  '李维斯',
#  '联名',
#  '小',
#  '夹克',
#  '儿',
#  '！',
#  '耀西真',
#  '可爱',
#  ' ',
#  '\xa0',
#  '[',
#  '组图',
#  '共',
#  '3',
#  '张',
#  ']',
#  '\xa0',
#  '原图',
#  '\xa0',
#  ' ',
#  '打算',
#  '做',
#  '视频',
#  '之前',
#  '休息',
#  '一会',
#  '→',
#  '看',
#  '一眼',
#  '直播',
#  '→',
#  '看到',
#  '有人',
#  '在',
#  '玩',
#  '奥特曼',
#  '游戏',
#  '→',
#  '勾起',
#  '回忆',
#  '→',
#  '看',
#  '了',
#  '一',
#  '整晚',
#  '的',
#  '奥特曼',
#  ' ',
#  '\xa0',
#  ' ',
#  '如何',
#  '让',
#  '脸',
#  '看上去',
#  '不',
#  '那么',
#  '长',
#  '：',
#  '强行',
#  '遮住',
#  '下巴',
#  ' ',
#  '\xa0',
#  '原图',
#  '\xa0',
#  ' ',
#  '分享',
#  '图片',
#  ' ',
#  '\xa0',
#  '原图',
#  '\xa0',
#  ' ',
#  '第一次',
#  '网课',
#  '考试',
#  '，',
#  '真是',
#  '有趣',
#  '的',
#  '体验',
#  '。',
#  '每当',
#  '抓耳挠腮',
#  '做',
#  '不',
#  '出来',
#  '的',
#  '时候',
#  '，',
#  '切',
#  '到',
#  '会议室',
#  '，',
#  '发现',
#  '同学',
#  '们',
#  '也',
#  '在',
#  '抓耳挠腮',
#  '，',
#  '我',
#  '就',
#  '放心',
#  '了',
#  '。',
#  ' ',
#  '\xa0',
#  ' ',
#  '还有',
#  '一天',
#  '就',
#  '考试',
#  '了',
#  '！',
#  '开启',
#  '临时',
#  '抱佛脚',
#  '模式',
#  '！',
#  ' ',
#  '\xa0',
#  ' ',
#  '#',
#  '世界',
#  '读书',
#  '日',
#  '#',
#  ' ',
#  '推荐',
#  '一下',
#  '《',
#  '围城',
#  '》',
#  '吧',
#  '，',
#  '特有',
#  '意思',
#  '。',
#  '高中',
#  '看',
#  '的',
#  '，',
#  '大学',
#  '时',
#  '出门',
#  '还',
#  '经常',
#  '揣着',
#  '在',
#  '飞机',
#  '上',
#  '重温',
#  '（',
#  '虽然',
#  '最后',
#  '都',
#  '睡着',
#  '了',
#  '）',
#  ' ',
#  '\xa0',
#  ' ',
#  '“',
#  '猫',
#  '”',
#  ' ',
#  '\xa0',
#  '原图',
#  '\xa0',
#  ' ',
#  '最近',
#  '不',
#  '知道',
#  '为啥',
#  '，',
#  '总',
#  '感觉',
#  '提不起',
#  '劲',
#  '，',
#  '很累',
#  '，',
#  '明明',
#  '也',
#  '没有',
#  '很',
#  '忙',
#  '。',
#  '是不是',
#  '我',
#  '的',
#  '内心',
#  '太想',
#  '返校',
#  '上学',
#  '了',
#  '。',
#  ' ',
#  '\xa0',
#  ' ',
#  '走',
#  '到',
#  '半路',
#  '下',
#  '暴雨',
#  '了',
#  '，',
#  '现在',
#  '是',
#  '一只',
#  '瑟瑟',
#  '发抖',
#  '的',
#  '落汤鸡',
#  ' ',
#  '\xa0',
#  ' ',
#  '下课',
#  '了',
#  '。',
#  '明天',
#  '早上',
#  '还要',
#  '起来',
#  '上课',
#  '。',
#  '头发',
#  '渐渐',
#  '消失',
#  '。',
#  ' ',
#  '\xa0',
#  ' ',
#  '他',
#  '感动',
#  '的',
#  '快要',
#  '哭',
#  '了',
#  '。',
#  ' ',
#  '_',
#  '老',
#  '番茄',
#  '_',
#  '的',
#  '微博',
#  '视频',
#  ' ',
#  '\xa0',
#  ' ',
#  '转发',
#  '理由',
#  ':',
#  '致敬',
#  '，',
#  '缅怀',
#  '。',
#  '\xa0',
#  '\xa0',
#  ' ',
#  '总算',
#  '做',
#  '完',
#  '视频',
#  '和',
#  '封面',
#  '了',
#  '，',
#  '但是',
#  '明天',
#  '还有',
#  '早课',
#  '和',
#  '作业',
#  '🙉',
#  '🙉',
#  '🙉',
#  '头发',
#  '要',
#  '掉',
#  '光',
#  '了',
#  '！',
#  ' ',
#  '\xa0',
#  '原图',
#  '\xa0',
#  ' ',
#  '不',
#  '知道',
#  '为什么',
#  '，',
#  '看到',
#  '这',
#  '只',
#  '就',
#  '想',
#  '笑',
#  ' ',
#  '\xa0',
#  '原图',
#  '\xa0',
#  ' ',
#  '这周',
#  '有个',
#  '四个',
#  '作业',
#  '要交',
#  '（',
#  '还',
#  '没',
#  '开始',
#  '）',
#  '，',
#  '如果',
#  '活过',
#  '这周',
#  '，',
#  '我',
#  '一定',
#  '好好',
#  '做',
#  '视频',
#  ' ',
#  '\xa0',
#  ' ',
#  '我',
#  '也',
#  '开始',
#  '了',
#  ' ',
#  '\xa0',
#  '原图',
#  '\xa0',
#  ' ',
#  '最近',
#  '外',
#  '卖点',
#  '太多',
#  '了',
#  '。',
#  '外卖',
#  '小哥',
#  '对',
#  '我',
#  '的',
#  '称呼',
#  '已经',
#  '从',
#  '“',
#  '张',
#  '先生',
#  '”',
#  '变成',
#  '了',
#  '“',
#  '张哥',
#  '”',
#  '，',
#  '现在',
#  '是',
#  '“',
#  '小张',
#  '”',
#  '了',
#  '。',
#  ' ',
#  '\xa0',
#  ' ',
#  '最近',
#  '天天',
#  '失眠',
#  '，',
#  '所以',
#  '今天',
#  '决定',
#  '睡前',
#  '做点',
#  '作业',
#  '，',
#  '帮助',
#  '自己',
#  '尽快',
#  '入眠',
#  ' ',
#  '\xa0',
#  ' ',
#  '晚睡',
#  '→',
#  '艰难',
#  '早起',
#  '上课',
#  '→',
#  '补觉',
#  '到',
#  '傍晚',
#  '→',
#  '晕乎乎',
#  '地',
#  '摸鱼',
#  '→',
#  '因为',
#  '补',
#  '了',
#  '觉',
#  '睡不着',
#  '→',
#  '晚睡',
#  '。',
#  ' ',
#  '\xa0',
#  '原图',
#  '\xa0',
#  ' ',
#  '小狗',
#  '为何',
#  '愁容满面',
#  ' ',
#  '\xa0',
#  '原图',
#  '\xa0',
#  ' ',
#  '谁',
#  '能',
#  '想到',
#  '，',
#  '正式',
#  '开始',
#  '上网',
#  '课',
#  '前一天',
#  '晚上',
#  '，',
#  '我',
#  '通宵',
#  '玩',
#  '了',
#  '一',
#  '晚上',
#  '扫雷',
#  '。',
#  ' ',
#  '\xa0',
#  ' ',
#  '宅',
#  '在家',
#  '有',
#  '什么',
#  '能',
#  '拍',
#  '的',
#  '生活区',
#  '视频',
#  '吗',
#  '，',
#  '想',
#  '不',
#  '出来',
#  '！',
#  ' ',
#  '\xa0',
#  ' ',
#  '理完',
#  '发了',
#  '，',
#  '终于',
#  '重见光明',
#  '了',
#  '。',
#  ' ',
#  '\xa0',
#  '原图',
#  '\xa0',
#  ' ',
#  '我',
#  '被',
#  '黑猫',
#  '警长',
#  '抓捕',
#  '了',
#  ' ',
#  '\xa0',
#  '原图',
#  '\xa0',
#  ' ',
#  '涂',
#  '润唇膏',
#  '的',
#  '时候',
#  '吃',
#  '了',
#  '一口',
#  '，',
#  '真',
#  '难吃',
#  '，',
#  '我',
#  '再也',
#  '不吃',
#  '润唇膏',
#  '了',
#  '。',
#  ' ',
#  '\xa0',
#  ' ',
#  '明天',
#  '要',
#  '开始',
#  '上网',
#  '课',
#  '了',
#  '，',
#  '有缘',
#  '再见',
#  ' ',
#  '\xa0',
#  ' ',
#  '不',
#  '小心',
#  '买',
#  '多',
#  '了',
#  '，',
#  '不得不',
#  '天天',
#  '啃',
#  '草',
#  '，',
#  '一天',
#  '啃',
#  '两顿',
#  '草',
#  ' ',
#  '_',
#  '老',
#  '番茄',
#  '_',
#  '的',
#  '微博',
#  '视频',
#  ' ',
#  '\xa0',
#  ' ',
#  '人类',
#  '的',
#  '本质',
#  ' ',
#  '\xa0',
#  '[',
#  '组图',
#  '共',
#  '2',
#  '张',
#  ']',
#  '\xa0',
#  '原图',
#  '\xa0',
#  ' ',
#  '很',
#  '懒',
#  '，',
#  '但',
#  '又',
#  '要',
#  '保证',
#  '膳食',
#  '均衡',
#  '，',
#  '于是',
#  '买',
#  '了',
#  '一',
#  '冰箱',
#  '的',
#  '黄瓜',
#  '，',
#  '现在',
#  '没事',
#  '就',
#  '啃',
#  '黄瓜',
#  '，',
#  '快',
#  '变成',
#  '黄瓜',
#  '人',
#  '了',
#  '。',
#  ' ',
#  '\xa0',
#  ' ',
#  '年前',
#  '忘',
#  ...]

# %%
word_list=[i for i in word_list if i not in stopwords_list]

# %%
word_list
# Out:
# ['复习',
#  '期末',
#  '几天',
#  '钻五到',
#  '钻',
#  '恭喜',
#  '席瑾',
#  '名',
#  '用户',
#  '1k',
#  '官方',
#  '唯一',
#  '抽奖',
#  '工具',
#  '抽奖',
#  '平台',
#  '本次',
#  '抽奖',
#  '监督',
#  '公正',
#  '公示',
#  '链接',
#  '抽奖',
#  '平台',
#  '庆祝',
#  '吃',
#  '鸡',
#  '抽',
#  '1k',
#  '明天',
#  '20',
#  '点',
#  '开奖',
#  '查看',
#  '庆祝',
#  '吃',
#  '鸡',
#  '抽',
#  '1k',
#  '明天',
#  '20',
#  '点',
#  '开奖',
#  '查看',
#  '一年',
#  '两度',
#  '万众',
#  '期待',
#  '考前',
#  '临时',
#  '抱佛脚',
#  '时间',
#  '默契',
#  '挑战',
#  'BOY',
#  '兄弟',
#  'YSL212',
#  '生日快乐',
#  '偶像',
#  '儿童节',
#  '快乐',
#  '希望',
#  '脸能',
#  '变回',
#  '小时候',
#  '圆润',
#  '梦想',
#  '鸡腿',
#  '利用',
#  '上课',
#  '开小差',
#  '时间',
#  '学',
#  '一点',
#  '蒙语',
#  '下次',
#  '回',
#  '内蒙',
#  '能看懂',
#  '蒙文',
#  '学期',
#  '开',
#  '小差',
#  'b',
#  '站',
#  '交',
#  '作业',
#  '上线',
#  '柯南',
#  '剧场版',
#  '可恶',
#  '柯南',
#  '昨晚',
#  '失眠',
#  '睡不着',
#  '翻来覆去',
#  '四点',
#  '钟',
#  '悟',
#  '好像',
#  '热得',
#  '睡不着',
#  '毅然',
#  '打开',
#  '空调',
#  '睡着',
#  '弟弟',
#  'call',
#  '查看',
#  '最强',
#  '大脑',
#  '陆英泽',
#  '最强',
#  '大脑',
#  '开播',
#  '##',
#  '最强',
#  '大脑',
#  '半小时',
#  '开播',
#  '拉',
#  '电视',
#  '访问',
#  't',
#  'heFOA',
#  '收看',
#  '网络',
#  '直播',
#  '完美',
#  '还原',
#  '世界',
#  '名画',
#  '说',
#  '画',
#  '挑战',
#  '天猫',
#  '搜索',
#  'OPPO',
#  '官方',
#  '旗舰店',
#  'get',
#  '同款',
#  '耳机',
#  '藏',
#  '黑影',
#  '中',
#  '怪兽',
#  '感谢',
#  '腾讯',
#  'NintendoSwitch',
#  '送',
#  '国行',
#  'switch',
#  '李维斯',
#  '联名',
#  '夹克',
#  '耀西真',
#  '可爱',
#  '打算',
#  '做',
#  '休息',
#  '一会',
#  '一眼',
#  '直播',
#  '有人',
#  '玩',
#  '奥特曼',
#  '游戏',
#  '勾起',
#  '回忆',
#  '整晚',
#  '奥特曼',
#  '脸',
#  '长',
#  '强行',
#  '遮住',
#  '下巴',
#  '分享',
#  '第一次',
#  '网课',
#  '考试',
#  '有趣',
#  '体验',
#  '抓耳挠腮',
#  '做',
#  '会议室',
#  '发现',
#  '同学',
#  '抓耳挠腮',
#  '放心',
#  '考试',
#  '开启',
#  '临时',
#  '抱佛脚',
#  '模式',
#  '世界',
#  '读书',
#  '日',
#  '推荐',
#  '围城',
#  '特有',
#  '高中',
#  '大学',
#  '时',
#  '出门',
#  '揣着',
#  '飞机',
#  '重温',
#  '睡着',
#  '猫',
#  '为啥',
#  '总',
#  '感觉',
#  '提不起',
#  '劲',
#  '很累',
#  '明明',
#  '忙',
#  '内心',
#  '太想',
#  '返校',
#  '上学',
#  '走',
#  '半路',
#  '暴雨',
#  '一只',
#  '发抖',
#  '落汤鸡',
#  '下课',
#  '明天',
#  '早上',
#  '上课',
#  '头发',
#  '渐渐',
#  '消失',
#  '感动',
#  '哭',
#  '致敬',
#  '缅怀',
#  '总算',
#  '做',
#  '完',
#  '封面',
#  '明天',
#  '早课',
#  '作业',
#  '🙉',
#  '🙉',
#  '🙉',
#  '头发',
#  '掉',
#  '想',
#  '笑',
#  '这周',
#  '有个',
#  '四个',
#  '作业',
#  '要交',
#  '活过',
#  '这周',
#  '好好',
#  '做',
#  '外',
#  '卖点',
#  '太多',
#  '外卖',
#  '小哥',
#  '称呼',
#  '张哥',
#  '小张',
#  '天天',
#  '失眠',
#  '睡前',
#  '做点',
#  '作业',
#  '入眠',
#  '晚睡',
#  '艰难',
#  '早起',
#  '上课',
#  '补觉',
#  '傍晚',
#  '晕乎乎',
#  '摸鱼',
#  '补',
#  '觉',
#  '睡不着',
#  '晚睡',
#  '小狗',
#  '愁容满面',
#  '想到',
#  '正式',
#  '上网',
#  '课',
#  '前一天',
#  '晚上',
#  '通宵',
#  '玩',
#  '晚上',
#  '扫雷',
#  '宅',
#  '在家',
#  '拍',
#  '生活区',
#  '想',
#  '理完',
#  '发了',
#  '终于',
#  '重见光明',
#  '黑猫',
#  '警长',
#  '抓捕',
#  '涂',
#  '润唇膏',
#  '吃',
#  '一口',
#  '真',
#  '难吃',
#  '再也',
#  '不吃',
#  '润唇膏',
#  '明天',
#  '上网',
#  '课',
#  '有缘',
#  '再见',
#  '小心',
#  '买',
#  '天天',
#  '啃',
#  '草',
#  '啃',
#  '两顿',
#  '草',
#  '人类',
#  '本质',
#  '懒',
#  '保证',
#  '膳食',
#  '均衡',
#  '买',
#  '冰箱',
#  '黄瓜',
#  '没事',
#  '啃',
#  '黄瓜',
#  '黄瓜',
#  '年前',
#  '忘',
#  '理发',
#  '夹',
#  '发卡',
#  '看得见',
#  '东西',
#  '真没想到',
#  '更新',
#  '真',
#  '不赖',
#  '好闲',
#  '新年快乐',
#  '夸夸',
#  '退烧',
#  '新年快乐',
#  '顺意',
#  '身体健康',
#  '分享',
#  '百大',
#  '回来',
#  '发烧',
#  '传染给',
#  '关',
#  '家里',
#  '原定',
#  '春节',
#  '发',
#  '做',
#  '对不起',
#  '期待',
#  '更新',
#  '观众们',
#  '血',
#  '氧',
#  '96',
#  '97',
#  '呼吸困难',
#  '好好',
#  '身体',
#  '瘫',
#  '复旦大学',
#  '康康',
#  '谁家',
#  '排面',
#  '上海财经大学',
#  '财大',
#  '排面',
#  '哔哩',
#  '哔哩',
#  '智能',
#  '姬',
#  'B',
#  '站',
#  '百大',
#  'UP',
#  '主',
#  '揭晓',
#  '喜欢',
#  'UP',
#  '主',
#  '加油',
#  '🙊',
#  '懵',
#  '谢谢',
#  '财大',
#  '上海财经大学',
#  '财大',
#  '排面',
#  '哔哩',
#  '哔哩',
#  '智能',
#  '姬',
#  'B',
#  '站',
#  '百大',
#  'UP',
#  '主',
#  '揭晓',
#  '喜欢',
#  'UP',
#  '主',
#  '加油',
#  '谢谢',
#  '太紧张',
#  '哈哈哈哈',
#  '百大',
#  '照片',
#  '拍',
#  '食人魔',
#  '为期',
#  '两天',
#  '寒假',
#  '学期结束',
#  '放假',
#  '开学',
#  '哈哈哈哈',
#  '沼王',
#  '烛光',
#  '晚餐',
#  '🕯',
#  '🕯',
#  '一门',
#  '期末',
#  '加油',
#  '我玩会',
#  '手机',
#  '拍照',
#  '问',
#  '发型师',
#  '发际',
#  '线高',
#  '说',
#  '不高',
#  '不高',
#  '脸',
#  '很长',
#  '显得',
#  '高',
#  '笑',
#  '哭',
#  '好久没',
#  '理发店',
#  '听到',
#  '小伙',
#  '头发',
#  '挺厚',
#  '夸奖',
#  '年度',
#  '最多',
#  '弹幕',
#  '泪目',
#  '哈哈哈哈',
#  '哈哈哈',
#  '2020',
#  '我来',
#  '每学期',
#  '期末',
#  '焦虑',
#  '时间',
#  '茄酱',
#  '找',
#  '男朋友',
#  '学期',
#  '学习',
#  '编程',
#  '水平',
#  '如图',
#  '考研',
#  '加油',
#  '吃',
#  '睡',
#  '冷冷的',
#  '冰雨',
#  '茄上',
#  '胡乱',
#  '拍',
#  '下雨',
#  '不想',
#  '上学',
#  '怪病',
#  '狗',
#  '仿佛',
#  '喂奶',
#  '奇怪',
#  '明明',
#  '记住',
#  '学期']

# %%
len(word_list)
# Out:
# 515

# %%
c={}

# %%
for x in word_list:
    if len(x) > 1  and x != '\r\n' and x != ' ':
        if(x not in c):
            c[x] = 1
        else:
            c[x] += 1
items = sorted(c.items(), key=lambda item: item[1], reverse=True)

# %%
items
# Out:
# [('明天', 5),
#  ('抽奖', 4),
#  ('作业', 4),
#  ('百大', 4),
#  ('哔哩', 4),
#  ('UP', 4),
#  ('加油', 4),
#  ('期末', 3),
#  ('1k', 3),
#  ('查看', 3),
#  ('时间', 3),
#  ('上课', 3),
#  ('学期', 3),
#  ('睡不着', 3),
#  ('最强', 3),
#  ('大脑', 3),
#  ('头发', 3),
#  ('黄瓜', 3),
#  ('排面', 3),
#  ('财大', 3),
#  ('哈哈哈哈', 3),
#  ('官方', 2),
#  ('平台', 2),
#  ('庆祝', 2),
#  ('20', 2),
#  ('开奖', 2),
#  ('期待', 2),
#  ('临时', 2),
#  ('抱佛脚', 2),
#  ('挑战', 2),
#  ('柯南', 2),
#  ('失眠', 2),
#  ('睡着', 2),
#  ('开播', 2),
#  ('直播', 2),
#  ('世界', 2),
#  ('奥特曼', 2),
#  ('分享', 2),
#  ('考试', 2),
#  ('抓耳挠腮', 2),
#  ('明明', 2),
#  ('上学', 2),
#  ('这周', 2),
#  ('好好', 2),
#  ('天天', 2),
#  ('晚睡', 2),
#  ('上网', 2),
#  ('晚上', 2),
#  ('润唇膏', 2),
#  ('更新', 2),
#  ('新年快乐', 2),
#  ('上海财经大学', 2),
#  ('智能', 2),
#  ('揭晓', 2),
#  ('喜欢', 2),
#  ('谢谢', 2),
#  ('不高', 2),
#  ('复习', 1),
#  ('几天', 1),
#  ('钻五到', 1),
#  ('恭喜', 1),
#  ('席瑾', 1),
#  ('用户', 1),
#  ('唯一', 1),
#  ('工具', 1),
#  ('本次', 1),
#  ('监督', 1),
#  ('公正', 1),
#  ('公示', 1),
#  ('链接', 1),
#  ('一年', 1),
#  ('两度', 1),
#  ('万众', 1),
#  ('考前', 1),
#  ('默契', 1),
#  ('BOY', 1),
#  ('兄弟', 1),
#  ('YSL212', 1),
#  ('生日快乐', 1),
#  ('偶像', 1),
#  ('儿童节', 1),
#  ('快乐', 1),
#  ('希望', 1),
#  ('脸能', 1),
#  ('变回', 1),
#  ('小时候', 1),
#  ('圆润', 1),
#  ('梦想', 1),
#  ('鸡腿', 1),
#  ('利用', 1),
#  ('开小差', 1),
#  ('一点', 1),
#  ('蒙语', 1),
#  ('下次', 1),
#  ('内蒙', 1),
#  ('能看懂', 1),
#  ('蒙文', 1),
#  ('小差', 1),
#  ('上线', 1),
#  ('剧场版', 1),
#  ('可恶', 1),
#  ('昨晚', 1),
#  ('翻来覆去', 1),
#  ('四点', 1),
#  ('好像', 1),
#  ('热得', 1),
#  ('毅然', 1),
#  ('打开', 1),
#  ('空调', 1),
#  ('弟弟', 1),
#  ('call', 1),
#  ('陆英泽', 1),
#  ('##', 1),
#  ('半小时', 1),
#  ('电视', 1),
#  ('访问', 1),
#  ('heFOA', 1),
#  ('收看', 1),
#  ('网络', 1),
#  ('完美', 1),
#  ('还原', 1),
#  ('名画', 1),
#  ('天猫', 1),
#  ('搜索', 1),
#  ('OPPO', 1),
#  ('旗舰店', 1),
#  ('get', 1),
#  ('同款', 1),
#  ('耳机', 1),
#  ('黑影', 1),
#  ('怪兽', 1),
#  ('感谢', 1),
#  ('腾讯', 1),
#  ('NintendoSwitch', 1),
#  ('国行', 1),
#  ('switch', 1),
#  ('李维斯', 1),
#  ('联名', 1),
#  ('夹克', 1),
#  ('耀西真', 1),
#  ('可爱', 1),
#  ('打算', 1),
#  ('休息', 1),
#  ('一会', 1),
#  ('一眼', 1),
#  ('有人', 1),
#  ('游戏', 1),
#  ('勾起', 1),
#  ('回忆', 1),
#  ('整晚', 1),
#  ('强行', 1),
#  ('遮住', 1),
#  ('下巴', 1),
#  ('第一次', 1),
#  ('网课', 1),
#  ('有趣', 1),
#  ('体验', 1),
#  ('会议室', 1),
#  ('发现', 1),
#  ('同学', 1),
#  ('放心', 1),
#  ('开启', 1),
#  ('模式', 1),
#  ('读书', 1),
#  ('推荐', 1),
#  ('围城', 1),
#  ('特有', 1),
#  ('高中', 1),
#  ('大学', 1),
#  ('出门', 1),
#  ('揣着', 1),
#  ('飞机', 1),
#  ('重温', 1),
#  ('为啥', 1),
#  ('感觉', 1),
#  ('提不起', 1),
#  ('很累', 1),
#  ('内心', 1),
#  ('太想', 1),
#  ('返校', 1),
#  ('半路', 1),
#  ('暴雨', 1),
#  ('一只', 1),
#  ('发抖', 1),
#  ('落汤鸡', 1),
#  ('下课', 1),
#  ('早上', 1),
#  ('渐渐', 1),
#  ('消失', 1),
#  ('感动', 1),
#  ('致敬', 1),
#  ('缅怀', 1),
#  ('总算', 1),
#  ('封面', 1),
#  ('早课', 1),
#  ('有个', 1),
#  ('四个', 1),
#  ('要交', 1),
#  ('活过', 1),
#  ('卖点', 1),
#  ('太多', 1),
#  ('外卖', 1),
#  ('小哥', 1),
#  ('称呼', 1),
#  ('张哥', 1),
#  ('小张', 1),
#  ('睡前', 1),
#  ('做点', 1),
#  ('入眠', 1),
#  ('艰难', 1),
#  ('早起', 1),
#  ('补觉', 1),
#  ('傍晚', 1),
#  ('晕乎乎', 1),
#  ('摸鱼', 1),
#  ('小狗', 1),
#  ('愁容满面', 1),
#  ('想到', 1),
#  ('正式', 1),
#  ('前一天', 1),
#  ('通宵', 1),
#  ('扫雷', 1),
#  ('在家', 1),
#  ('生活区', 1),
#  ('理完', 1),
#  ('发了', 1),
#  ('终于', 1),
#  ('重见光明', 1),
#  ('黑猫', 1),
#  ('警长', 1),
#  ('抓捕', 1),
#  ('一口', 1),
#  ('难吃', 1),
#  ('再也', 1),
#  ('不吃', 1),
#  ('有缘', 1),
#  ('再见', 1),
#  ('小心', 1),
#  ('两顿', 1),
#  ('人类', 1),
#  ('本质', 1),
#  ('保证', 1),
#  ('膳食', 1),
#  ('均衡', 1),
#  ('冰箱', 1),
#  ('没事', 1),
#  ('年前', 1),
#  ('理发', 1),
#  ('发卡', 1),
#  ('看得见', 1),
#  ('东西', 1),
#  ('真没想到', 1),
#  ('不赖', 1),
#  ('好闲', 1),
#  ('夸夸', 1),
#  ('退烧', 1),
#  ('顺意', 1),
#  ('身体健康', 1),
#  ('回来', 1),
#  ('发烧', 1),
#  ('传染给', 1),
#  ('家里', 1),
#  ('原定', 1),
#  ('春节', 1),
#  ('对不起', 1),
#  ('观众们', 1),
#  ('96', 1),
#  ('97', 1),
#  ('呼吸困难', 1),
#  ('身体', 1),
#  ('复旦大学', 1),
#  ('康康', 1),
#  ('谁家', 1),
#  ('太紧张', 1),
#  ('照片', 1),
#  ('食人魔', 1),
#  ('为期', 1),
#  ('两天', 1),
#  ('寒假', 1),
#  ('学期结束', 1),
#  ('放假', 1),
#  ('开学', 1),
#  ('沼王', 1),
#  ('烛光', 1),
#  ('晚餐', 1),
#  ('一门', 1),
#  ('我玩会', 1),
#  ('手机', 1),
#  ('拍照', 1),
#  ('发型师', 1),
#  ('发际', 1),
#  ('线高', 1),
#  ('很长', 1),
#  ('显得', 1),
#  ('好久没', 1),
#  ('理发店', 1),
#  ('听到', 1),
#  ('小伙', 1),
#  ('挺厚', 1),
#  ('夸奖', 1),
#  ('年度', 1),
#  ('最多', 1),
#  ('弹幕', 1),
#  ('泪目', 1),
#  ('哈哈哈', 1),
#  ('2020', 1),
#  ('我来', 1),
#  ('每学期', 1),
#  ('焦虑', 1),
#  ('茄酱', 1),
#  ('男朋友', 1),
#  ('学习', 1),
#  ('编程', 1),
#  ('水平', 1),
#  ('如图', 1),
#  ('考研', 1),
#  ('冷冷的', 1),
#  ('冰雨', 1),
#  ('茄上', 1),
#  ('胡乱', 1),
#  ('下雨', 1),
#  ('不想', 1),
#  ('怪病', 1),
#  ('仿佛', 1),
#  ('喂奶', 1),
#  ('奇怪', 1),
#  ('记住', 1)]

# %%
with open('cipin_lfq.txt','a',encoding='utf-8') as f:
    for i in items:
        f.write(i[0]+'  '+str(i[1])+'\n')

# %%
text = ' '.join(word_list)

# %%
def word_cloud(text):
    wc = wordcloud.WordCloud(background_color='white',
                             width=1000,
                             height=600,
                             font_path='Consolas-with-Yahei Nerd Font.ttf')
    cloud = wc.generate(text)
    plt.imshow(wc)
    plt.axis('off')
    plt.show()
    return wc

# %%
word_cloud(text).to_file('yyqx_wordcloud.jpg')
