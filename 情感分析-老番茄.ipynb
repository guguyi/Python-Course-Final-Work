# %%
import jieba
import re
import csv
import wordcloud
import matplotlib.pyplot as plt

# %%
csv_name = 'lfq_csv.csv'  # 微博信息文件

# %%
with open(csv_name, 'r', encoding='utf-8') as f:
    """
        读取微博信息到info列表
        info: type: list
    """
    reader = csv.reader(f)
    info = [row[1:]for row in reader][1:]

# %%
info[:20]
# Out:
# [['复习期末的这几天，我从钻五到了钻一。 \xa0', 'True'],
#  ['转发理由:恭喜@-席瑾- 1名用户获得【1k】。微博官方唯一抽奖工具@微博抽奖平台 对本次抽奖进行监督，结果公正有效。公示链接：微博抽奖平台 //@_老番茄_:庆祝吃鸡，转发抽1k！明天20点开奖！ 查看图片\xa0\xa0',
#   'False'],
#  ['转发理由:庆祝吃鸡，转发抽1k！明天20点开奖！ 查看图片\xa0\xa0', 'False'],
#  ['又到了一年两度，万众期待的考前临时抱佛脚时间 \xa0', 'True'],
#  ['默契挑战！看看我和BOY谁才是真正的好兄弟#YSL212#  _老番茄_的微博视频 \xa0', 'True'],
#  ['生日快乐，我的偶像 _老番茄_的微博视频 \xa0', 'True'],
#  ['儿童节快乐！希望我的脸能变回小时候那么圆润！ \xa0原图\xa0', 'True'],
#  ['失去梦想变成大鸡腿 \xa0原图\xa0', 'True'],
#  ['决定利用每天上课开小差的时间学一点蒙语。如果下次回内蒙能看懂蒙文了，说明我这学期一定开了很多小差。 \xa0原图\xa0', 'True'],
#  ['为什么b站在我要交作业之前上线柯南剧场版。可恶，已经看了一天柯南了。 \xa0', 'True'],
#  ['昨晚失眠睡不着，翻来覆去。四点钟的时候，突然悟到，好像是热得睡不着。于是毅然打开了空调，立马睡着了。 \xa0', 'True'],
#  ['转发理由:给我的好弟弟打call 查看图片 //@最强大脑陆英泽:#最强大脑开播##最强大脑#还有半小时就要开播拉，看不了电视的也可以访问http://t.cn/heFOA收看网络直播\xa0\xa0',
#   'False'],
#  ['完美还原世界名画！你说我画挑战。天猫搜索OPPO官方旗舰店get同款耳机  _老番茄_的微博视频 \xa0', 'True'],
#  ['藏在黑影中的小怪兽 _老番茄_的微博视频 \xa0', 'True'],
#  ['感谢@腾讯NintendoSwitch 送的国行switch和李维斯联名小夹克儿！耀西真可爱 \xa0[组图共3张]\xa0原图\xa0',
#   'True'],
#  ['打算做视频之前休息一会→看一眼直播→看到有人在玩奥特曼游戏→勾起回忆→看了一整晚的奥特曼 \xa0', 'True'],
#  ['如何让脸看上去不那么长：强行遮住下巴 \xa0原图\xa0', 'True'],
#  ['分享图片 \xa0原图\xa0', 'True'],
#  ['第一次网课考试，真是有趣的体验。每当抓耳挠腮做不出来的时候，切到会议室，发现同学们也在抓耳挠腮，我就放心了。 \xa0', 'True'],
#  ['还有一天就考试了！开启临时抱佛脚模式！ \xa0', 'True']]

# %%
with open(csv_name, 'r', encoding='utf-8') as f:
    """
        读取微博内容到content列表
        content: type: list
    """
    reader = csv.reader(f)
    content = [row[1]for row in reader][1:]

# %%
with open(csv_name, 'r', encoding='utf-8') as f:
    """
        读取微博内容到content列表
        is_original: type: list
    """
    reader = csv.reader(f)
    is_original = [row[2]for row in reader][1:]

# %%
weibo_num = len(info)  # 数据集中微博总数
original_num = is_original.count('True')  # 原创微博数量
repost_num = is_original.count('False')  # 转发微博数量

# %%
print(weibo_num,original_num,repost_num)
# Out:
# 71 64 7

# %%
original_list = [i[0] for i in info if i[1] == 'True']  # 原创微博列表
repost_list = [i[0] for i in info if i[1] == 'False']  # 转发微博列表

# %%
def read_list_file(filename):
    """
        读取文件中内容为列表的txt文件(每行以'\n'分隔)
        如: 停用词，否定词，程度副词
        filename: 文件路径
        return:file_list type: list
    """
    file_list = [k.strip() for k in open(
        filename, encoding='utf-8').readlines() if k.strip() != '\n']
    return file_list

# %%
def read_dict_file(filename):
    """
        读取文件中内容为键值对的txt文件
        如: BosonNLP情感词典
        filename: 文件路径
        return: classify_dict tyoe: dict
    """
    classify_list = [k.strip() for k in open(
        filename, encoding='utf-8').readlines() if k.strip() != '\n']
    classify_dict = dict()
    for i in classify_list:
        if len(i.split(' ')) == 2:
            classify_dict[i.split(' ')[0]] = i.split(' ')[1]
    return classify_dict

# %%
def jieba_cut(string, stopwords, emoji_dict):
    """
        对每一条微博进行jieba分词并去除停用词
        string: 微博 type: str
        stopwords: 停用词列表 type: list
        return: 去除停用词后的分词列表
    """
    string = string.replace(u'\xa0', u' ')  # 将\xa0字符替换为' '
    word_list = jieba.lcut(string)
    word_list = [i for i in word_list if i not in stopwords and i != ' ']
    for i in range(0, len(word_list)):
        if word_list[i] in emoji_dict.keys():
            word_list[i] = str(emoji_dict[word_list[i]])
    return word_list

# %%
# BosonNLP情感词典
BosonNLP = 'senti_dict/BosonNLP_sentiment_score/BosonNLP_sentiment_score/BosonNLP_sentiment_score.txt'
BosonNLP_dict = read_dict_file(BosonNLP)  # 读取情感词典内容到dcit中

# 否定词列表
Nega = 'senti_dict/polar_dict/nega_dict.txt'
Nega_list = read_list_file(Nega)  # 读取否定词内容到list中

# 程度副词
degree = 'senti_dict/polar_dict/degree_dict.txt'
degree_dict = read_dict_file(degree)  # 读取程度副词词典内容到dict中

# 停用词
stop_file = 'senti_dict/stopwords/stopwords.txt'
stopwords = read_list_file(stop_file)  # 读取程度副词词典内容到list中

# emoji词典
emoji_file = 'senti_dict/emoji_dict/emoji.txt'
emoji_dict = read_dict_file(emoji_file)   # 读取emoji词典内容到dict中

# %%
emoji_dict
# Out:
# {'⚽': "{'足球'}",
#  '🎆': "{'焰火'}",
#  '🎇': "{'烟花'}",
#  '🎁': "{'礼物'}",
#  '🎖': "{'勋章'}",
#  '🇨🇳': "{'中国'}",
#  '🏁': "{'终点'}",
#  '🇦🇩': "{'安道尔'}",
#  '🇦🇪': "{'阿拉伯联合大公国'}",
#  '🇦🇫': "{'阿富汗'}",
#  '🇦🇱': "{'阿尔巴尼亚'}",
#  '🇦🇲': "{'亚美尼亚'}",
#  '🇦🇷': "{'阿根廷共和国'}",
#  '🇦🇶': "{'南极洲'}",
#  '🇦🇴': "{'安哥拉'}",
#  '🇦🇹': "{'奥地利'}",
#  '🇦🇺': "{'澳大利亚'}",
#  '🇧🇪': "{'比利时'}",
#  '🇧🇩': "{'孟加拉国'}",
#  '🇧🇭': "{'巴林'}",
#  '🇧🇬': "{'保加利亚'}",
#  '🇧🇳': "{'文莱'}",
#  '🇧🇷': "{'巴西'}",
#  '🇧🇴': "{'玻利维亚'}",
#  '🇨🇦': "{'加拿大'}",
#  '🥪': "{'三明治'}",
#  '☢': "{'辐射'}",
#  '♈': "{'白羊座'}",
#  '♌': "{'狮子座'}",
#  '♉': "{'金牛座'}",
#  '♊': "{'双子座'}",
#  '♑': "{'摩羯座'}",
#  '♋': "{'巨蟹座'}",
#  '♎': "{'天秤座'}",
#  '♍': "{'处女座'}",
#  '♏': "{'天蝎座'}",
#  '♓': "{'双鱼座'}",
#  '🚾': "{'厕所'}",
#  '♿': "{'轮椅'}",
#  '🛂': "{'护照'}",
#  '🛃': "{'海关'}",
#  '🛅': "{'寄存'}",
#  '㊗': "{'祝贺'}",
#  '㊙': "{'秘密'}",
#  '🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f': "{'英格兰'}",
#  '🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f': "{'苏格兰'}",
#  '🇿🇲': "{'赞比亚'}",
#  '🇿🇼': "{'津巴布韦'}",
#  '🇿🇦': "{'南非'}",
#  '🇾🇪': "{'也门'}",
#  '🇻🇳': "{'越南'}",
#  '🇻🇪': "{'委内瑞拉'}",
#  '🇺🇾': "{'乌拉圭'}",
#  '🇻🇦': "{'梵蒂冈'}",
#  '🇺🇸': "{'美国'}",
#  '🇺🇳': "{'联合国'}",
#  '🇺🇦': "{'乌克兰'}",
#  '🇺🇬': "{'乌干达'}",
#  '🇹🇼': "{'台湾'}",
#  '🇹🇷': "{'土耳其'}",
#  '🇹🇳': "{'突尼斯'}",
#  '🇹🇭': "{'泰国'}",
#  '🇸🇲': "{'圣马力诺'}",
#  '🇸🇳': "{'塞内加尔'}",
#  '🇸🇰': "{'斯洛伐克共和国'}",
#  '🇨🇿': "{'捷克共和国'}",
#  '🇸🇪': "{'瑞典'}",
#  '🇸🇩': "{'苏丹'}",
#  '🇷🇼': "{'卢旺达共和国'}",
#  '🇷🇺': "{'俄罗斯'}",
#  '🇷🇸': "{'塞尔维亚'}",
#  '🇷🇴': "{'罗马尼亚'}",
#  '🇵🇹': "{'葡萄牙'}",
#  '🇵🇸': "{'巴勒斯坦'}",
#  '🇵🇷': "{'波多黎各'}",
#  '🇵🇱': "{'波兰'}",
#  '🇵🇰': "{'巴基斯坦'}",
#  '🇵🇭': "{'菲律宾'}",
#  '🇵🇬': "{'新几内亚岛'}",
#  '🇵🇪': "{'秘鲁'}",
#  '🇵🇦': "{'巴拿马'}",
#  '🇴🇲': "{'阿曼'}",
#  '🇳🇿': "{'纽西兰'}",
#  '🇳🇴': "{'挪威'}",
#  '🇳🇱': "{'荷兰'}",
#  '🇳🇮': "{'尼加拉瓜'}",
#  '🇳🇦': "{'纳米比亚共和国'}",
#  '🇲🇾': "{'马来西亚'}",
#  '🇲🇿': "{'莫桑比克'}",
#  '🇲🇽': "{'墨西哥'}",
#  '🇲🇹': "{'马耳他'}",
#  '🇲🇴': "{'澳门'}",
#  '🇲🇳': "{'外蒙古'}",
#  '🇲🇲': "{'缅甸'}",
#  '🇲🇱': "{'马利共和国'}",
#  '🇲🇰': "{'马其顿王国'}",
#  '🇲🇩': "{'摩尔多瓦共和国'}",
#  '🇱🇾': "{'利比亚'}",
#  '🇱🇺': "{'卢森堡'}",
#  '🇱🇹': "{'立陶宛'}",
#  '🇱🇧': "{'黎巴嫩'}",
#  '🇱🇦': "{'老挝'}",
#  '🇰🇿': "{'哈萨克共和国'}",
#  '🇰🇼': "{'科威特'}",
#  '🇰🇵': "{'朝鲜'}",
#  '🇰🇷': "{'韩国'}",
#  '🇯🇵': "{'日本'}",
#  '🇯🇴': "{'约旦'}",
#  '🇯🇲': "{'牙买加'}",
#  '🇮🇹': "{'意大利'}",
#  '🇮🇶': "{'伊拉克'}",
#  '🇮🇷': "{'伊朗'}",
#  '🇮🇸': "{'冰岛'}",
#  '🇮🇳': "{'印度'}",
#  '🇮🇱': "{'以色列'}",
#  '🇮🇪': "{'爱尔兰'}",
#  '🇭🇰': "{'香港'}",
#  '🇬🇾': "{'圭亚那'}",
#  '🇬🇺': "{'关岛'}",
#  '🇬🇹': "{'危地马拉'}",
#  '🇬🇷': "{'希腊'}",
#  '🇬🇶': "{'赤道几内亚'}",
#  '🇬🇳': "{'几内亚'}",
#  '🇫🇷': "{'法国'}",
#  '🇫🇲': "{'密克罗尼西亚'}",
#  '🇫🇯': "{'斐济'}",
#  '🇫🇮': "{'芬兰'}",
#  '🇪🇬': "{'埃及'}",
#  '🇪🇪': "{'爱沙尼亚'}",
#  '🇩🇲': "{'多米尼加'}",
#  '🇩🇴': "{'多米尼加共和国'}",
#  '🇩🇰': "{'丹麦'}",
#  '🇩🇿': "{'阿尔及利亚'}",
#  '🇩🇯': "{'吉布提'}",
#  '🇨🇱': "{'智利'}",
#  '🇨🇫': "{'中非共和国'}",
#  '🚓': "{'一一○'}",
#  '↑': "{'一上'}",
#  '↓': "{'一下'}",
#  '⏳': "{'一下子'}",
#  '1️⃣': "{'一个'}",
#  '🎌': "{'交叉'}",
#  '⬛': "{'黑色'}",
#  '\U0001f7e5': "{'红色'}",
#  '\U0001f7e6': "{'蓝色'}",
#  '\U0001f7e8': "{'黄色'}",
#  '\U0001f7e9': "{'绿色'}",
#  '\U0001f7ea': "{'紫色'}",
#  '\U0001f7eb': "{'棕色'}",
#  '⚪': "{'圆形'}",
#  '🔷': "{'菱形'}",
#  '🔺': "{'三角形'}",
#  '🌜': "{'月色'}",
#  '🥵': "{'酷热'}",
#  '🈁': "{'这里'}",
#  '🏎': "{'赛车'}",
#  '🈂': "{'小费'}",
#  '🈚': "{'免费'}",
#  '🈯': "{'保留'}",
#  '🚫': "{'禁止'}",
#  '🈳': "{'空位'}",
#  '💺': "{'坐位'}",
#  '🈴': "{'合格'}",
#  '🈵': "{'客满'}",
#  '🈶': "{'付费'}",
#  '🈸': "{'申请'}",
#  '🈺': "{'营业'}",
#  '🉑': "{'可行'}",
#  '🔡': "{'小写'}",
#  '🔢': "{'数字'}",
#  '🔤': "{'拉丁字母'}",
#  '🆖': "{'不好'}",
#  '🆑': "{'清除'}",
#  '®': "{'注册'}",
#  '❗': "{'感叹'}",
#  '♻': "{'回收'}",
#  '♾': "{'无限'}",
#  '⚕': "{'医疗'}",
#  '⚜': "{'百合花'}",
#  '✔': "{'打勾'}",
#  '✖': "{'乘号'}",
#  '❇': "{'火花'}",
#  '❌': "{'打叉'}",
#  '➕': "{'加号'}",
#  '➖': "{'减号'}",
#  '➗': "{'除号'}",
#  '➰': "{'卷曲'}",
#  '⭕': "{'圆圈'}",
#  '〰': "{'破折号'}",
#  '📛': "{'姓名'}",
#  '🔱': "{'画戟'}",
#  '🔰': "{'新手'}",
#  '🎨': "{'画板'}",
#  '⏩': "{'前进'}",
#  '↗': "{'上升'}",
#  '⏸': "{'暂停'}",
#  '⏹': "{'停止'}",
#  '⏺': "{'录制'}",
#  '🎛': "{'控制'}",
#  '▶': "{'播放'}",
#  '📴': "{'关机'}",
#  '🔀': "{'随机变数'}",
#  '🔆': "{'亮度'}",
#  '🔼': "{'向上'}",
#  '♒': "{'宝瓶座'}",
#  '☦': "{'正教'}",
#  '☪': "{'伊斯兰教'}",
#  '☮': "{'和平'}",
#  '☸': "{'法轮'}",
#  '✡': "{'犹太教'}",
#  '🕎': "{'烛台'}",
#  '↔': "{'箭头'}",
#  '⚠': "{'警告'}",
#  '🚭': "{'禁烟'}",
#  '🏧': "{'提款'}",
#  '🚼': "{'宝宝'}",
#  '⚰': "{'棺材'}",
#  '🚬': "{'香烟'}",
#  '🗿': "{'石像'}",
#  '\U0001fa91': "{'椅子'}",
#  '🧽': "{'海绵'}",
#  '🧹': "{'扫帚'}",
#  '🧷': "{'别针'}",
#  '🧴': "{'化妆品'}",
#  '🧯': "{'灭火器'}",
#  '🛋': "{'沙发'}",
#  '🚿': "{'淋浴'}",
#  '🛁': "{'浴缸'}",
#  '🚽': "{'马桶'}",
#  '\U0001fa78': "{'滴血'}",
#  '🎞': "{'胶片'}",
#  '📡': "{'天线'}",
#  '🛰': "{'卫星'}",
#  '🔬': "{'显微镜'}",
#  '🔭': "{'望远镜'}",
#  '🧪': "{'试管'}",
#  '🧫': "{'培养皿'}",
#  '🔨': "{'锤子'}",
#  '⚔': "{'交战'}",
#  '⚙': "{'齿轮'}",
#  '⚖': "{'天平'}",
#  '⛏': "{'十字镐'}",
#  '🏹': "{'弓箭'}",
#  '🔗': "{'连接'}",
#  '🔫': "{'手枪'}",
#  '👨\u200d🔧': "{'钳工'}",
#  '👨\u200d🏭': "{'铆接'}",
#  '🗡': "{'匕首'}",
#  '🛡': "{'盾牌'}",
#  '👨\u200d\U0001f9af': "{'拄杖'}",
#  '🧰': "{'工具'}",
#  '🧲': "{'磁铁'}",
#  '🔑': "{'钥匙'}",
#  '🔒': "{'闭锁'}",
#  '✂': "{'剪刀'}",
#  '📁': "{'资料文件'}",
#  '📄': "{'文件'}",
#  '📅': "{'日历'}",
#  '🍹': "{'饮料'}",
#  '📆': "{'日历年度'}",
#  '📇': "{'卡片'}",
#  '📊': "{'条形图'}",
#  '📌': "{'图钉'}",
#  '📍': "{'大头针'}",
#  '📎': "{'回形针'}",
#  '📏': "{'直尺'}",
#  '🗃': "{'卡片目录'}",
#  '🗂': "{'索引'}",
#  '🗄': "{'柜子'}",
#  '🗑': "{'垃圾桶'}",
#  '👥': "{'双簧'}",
#  '*': "{'星号'}",
#  'test': "{'测试'}",
#  '☁': "{'云'}",
#  '☇': "{'闪电'}",
#  '⏱': "{'秒表'}",
#  '⏰': "{'闹钟'}",
#  '⌨': "{'键盘'}",
#  '☀': "{'太阳'}",
#  '⌚': "{'手表'}",
#  '☈': "{'雷雨'}",
#  '☂': "{'伞'}",
#  '⌛': "{'沙漏'}",
#  '💩': "{'大便'}",
#  '🕷': "{'蜘蛛'}",
#  '🍕': "{'披萨'}",
#  '🍨': "{'冰淇淋'}",
#  '\U0001fa73': "{'短裤'}",
#  '👻': "{'鬼'}",
#  '🍋': "{'柠檬'}",
#  '🍶': "{'清酒'}",
#  '🚝': "{'单轨'}",
#  '🚲': "{'自行车'}",
#  '🌽': "{'玉米'}",
#  '🚶': "{'行人'}",
#  '🎭': "{'面具'}",
#  '🍜': "{'面条'}",
#  '🤷': "{'耸肩'}",
#  '⛽': "{'油泵'}",
#  '😑': "{'无语'}",
#  '🍙': "{'饭团'}",
#  '🧟': "{'僵尸'}",
#  '🦠': "{'细菌'}",
#  '🤤': "{'流口水'}",
#  '🥜': "{'花生'}",
#  '\U0001fa72': "{'三角裤'}",
#  '💏': "{'亲吻'}",
#  '📢': "{'喇叭'}",
#  '🛶': "{'独木舟'}",
#  '🎺': "{'小号'}",
#  '🥈': "{'银牌'}",
#  '🛣': "{'高速公路'}",
#  '🦔': "{'刺猬'}",
#  '☿': "{'水星'}",
#  '🖐': "{'手掌'}",
#  '🍇': "{'葡萄'}",
#  '🏓': "{'乒乓球'}",
#  '🎿': "{'滑雪'}",
#  '⛪': "{'教堂'}",
#  '🐖': "{'猪'}",
#  '🧣': "{'围巾'}",
#  '😠': "{'生气'}",
#  '🦒': "{'长颈鹿'}",
#  '🥢': "{'筷子'}",
#  '🦌': "{'鹿'}",
#  '🎅': "{'圣诞老人'}",
#  '🐍': "{'蛇'}",
#  '😋': "{'好吃'}",
#  '🚉': "{'车站'}",
#  '🥓': "{'培根'}",
#  '🥏': "{'飞盘'}",
#  '📝': "{'备忘录'}",
#  '⛅': "{'阴'}",
#  '🚡': "{'索道'}",
#  '🌪': "{'龙卷风'}",
#  '🦂': "{'蝎子'}",
#  '👘': "{'和服'}",
#  '🐾': "{'爪印'}",
#  '🥮': "{'月饼'}",
#  '😨': "{'害怕'}",
#  '🏨': "{'酒店'}",
#  '👁': "{'眼睛'}",
#  '\U0001f9ca': "{'冰块'}",
#  '💢': "{'怒'}",
#  '❄': "{'雪花'}",
#  '🍺': "{'啤酒'}",
#  '♣': "{'梅花'}",
#  '✏': "{'铅笔'}",
#  '🎫': "{'票'}",
#  '🏟': "{'体育馆'}",
#  '🍧': "{'刨冰'}",
#  '🐛': "{'毛毛虫'}",
#  '🍂': "{'落叶'}",
#  '⛸': "{'滑冰'}",
#  '😖': "{'困惑'}",
#  '🐞': "{'瓢虫'}",
#  '🦅': "{'鹰'}",
#  '👂': "{'耳朵'}",
#  '🏜': "{'沙漠'}",
#  '🌩': "{'打雷'}",
#  '🌵': "{'仙人掌'}",
#  '💣': "{'炸弹'}",
#  '🎐': "{'风铃'}",
#  '🤸': "{'侧手翻'}",
#  '👣': "{'脚印'}",
#  '🕌': "{'清真寺'}",
#  '🧛': "{'吸血鬼'}",
#  '💥': "{'爆炸'}",
#  '🎒': "{'书包'}",
#  '🐎': "{'马'}",
#  '🚌': "{'公交车'}",
#  '💓': "{'心跳'}",
#  '⛄': "{'雪人'}",
#  '🌺': "{'芙蓉'}",
#  '🐚': "{'海螺'}",
#  '🎡': "{'摩天轮'}",
#  '😦': "{'啊'}",
#  '🐵': "{'猴头'}",
#  '🌰': "{'栗子'}",
#  '💎': "{'宝石'}",
#  '🍤': "{'天妇罗'}",
#  '🦴': "{'骨头'}",
#  '😲': "{'震惊'}",
#  '🔪': "{'菜刀'}",
#  '🌡': "{'温度计'}",
#  '🚇': "{'地铁'}",
#  '🍍': "{'菠萝'}",
#  '🍊': "{'橘子'}",
#  '🤧': "{'打喷嚏'}",
#  '😛': "{'吐舌'}",
#  '💀': "{'头骨'}",
#  '💄': "{'唇膏'}",
#  '🖊': "{'笔'}",
#  '🍣': "{'寿司'}",
#  '😞': "{'失望'}",
#  '🥁': "{'鼓'}",
#  '😔': "{'沉思'}",
#  '🐌': "{'蜗牛'}",
#  '♪': "{'八分音符'}",
#  '🕐': "{'一点'}",
#  '🧩': "{'拼图'}",
#  '🤑': "{'发财'}",
#  '🍸': "{'鸡尾酒'}",
#  '👅': "{'舌头'}",
#  '🧧': "{'红包'}",
#  '🏫': "{'学校'}",
#  '🏄': "{'冲浪'}",
#  '💡': "{'灯泡'}",
#  '🤘': "{'摇滚'}",
#  '🍓': "{'草莓'}",
#  '🏏': "{'板球'}",
#  '🧵': "{'线'}",
#  '🤥': "{'说谎'}",
#  '😷': "{'感冒'}",
#  '🦏': "{'犀牛'}",
#  '👛': "{'钱包'}",
#  '👵': "{'老奶奶'}",
#  '📣': "{'扩音器'}",
#  '🥂': "{'碰杯'}",
#  '🥔': "{'土豆'}",
#  '🐋': "{'鲸鱼'}",
#  '🕉': "{'奥姆'}",
#  '🏷': "{'标签'}",
#  '🖵': "{'屏幕'}",
#  '🛍': "{'购物袋'}",
#  '🥅': "{'球门'}",
#  '👔': "{'领带'}",
#  '🦢': "{'天鹅'}",
#  '🦐': "{'虾'}",
#  '🐇': "{'兔子'}",
#  '📒': "{'账本'}",
#  '🌋': "{'火山'}",
#  '😢': "{'哭'}",
#  '🍪': "{'饼干'}",
#  '🍡': "{'团子'}",
#  '🐘': "{'大象'}",
#  '🤰': "{'孕妇'}",
#  '🍴': "{'刀叉'}",
#  '😏': "{'得意'}",
#  '🥇': "{'金牌'}",
#  '🤝': "{'握手'}",
#  '🧱': "{'砖'}",
#  '🔋': "{'电池'}",
#  '😁': "{'嘻嘻'}",
#  '🐪': "{'骆驼'}",
#  '🗻': "{'富士山'}",
#  '🤔': "{'想一想'}",
#  '🦷': "{'牙齿'}",
#  '📼': "{'录像带'}",
#  '🐟': "{'鱼'}",
#  '💳': "{'信用卡'}",
#  '🚚': "{'货车'}",
#  '🤾': "{'手球'}",
#  '🤴': "{'王子'}",
#  '📨': "{'来信'}",
#  '🙇': "{'鞠躬'}",
#  '🦓': "{'斑马'}",
#  '📰': "{'报纸'}",
#  '\U0001f9c8': "{'黄油'}",
#  '\U0001f9a6': "{'水獭'}",
#  '🐝': "{'蜜蜂'}",
#  '🍔': "{'汉堡'}",
#  '🍅': "{'西红柿'}",
#  '\U0001f9a8': "{'臭鼬'}",
#  '🏀': "{'篮球'}",
#  '🧤': "{'手套'}",
#  '🏒': "{'冰球'}",
#  '🚎': "{'无轨电车'}",
#  '🏥': "{'医院'}",
#  '👑': "{'皇冠'}",
#  '🤮': "{'呕吐'}",
#  '♃': "{'木星'}",
#  '😡': "{'怒火中烧'}",
#  '🏦': "{'银行'}",
#  '👓': "{'眼镜'}",
#  '🎳': "{'保龄球'}",
#  '⚾': "{'棒球'}",
#  '🐆': "{'豹子'}",
#  '🥄': "{'匙'}",
#  '🏐': "{'排球'}",
#  '🚪': "{'门'}",
#  '🌑': "{'朔月'}",
#  '🛸': "{'飞碟'}",
#  '👪': "{'家庭'}",
#  '🥝': "{'猕猴桃'}",
#  '🥚': "{'蛋'}",
#  '🦞': "{'龙虾'}",
#  '🎩': "{'礼帽'}",
#  '💾': "{'软盘'}",
#  '🔮': "{'水晶球'}",
#  '🏂': "{'滑雪板'}",
#  '😤': "{'傲慢'}",
#  '😳': "{'脸红'}",
#  '🕯': "{'蜡烛'}",
#  '👜': "{'手提包'}",
#  '🧮': "{'算盘'}",
#  '😃': "{'哈哈'}",
#  '🐡': "{'河豚'}",
#  '⛈': "{'雷阵雨'}",
#  '🦑': "{'乌贼'}",
#  '🥌': "{'冰壶'}",
#  '😍': "{'花痴'}",
#  '💮': "{'白花'}",
#  '🚕': "{'出租车'}",
#  '\U0001f9c5': "{'洋葱'}",
#  '👚': "{'女装'}",
#  '🧨': "{'爆竹'}",
#  '🌳': "{'落叶树'}",
#  '🦜': "{'鹦鹉'}",
#  '📷': "{'相机'}",
#  '⚲': "{'中性'}",
#  '😕': "{'困扰'}",
#  '🛤': "{'铁轨'}",
#  '🐬': "{'海豚'}",
#  '🔖': "{'书签'}",
#  '🎧': "{'耳机'}",
#  '😘': "{'飞吻'}",
#  '🏆': "{'奖杯'}",
#  '😬': "{'龇牙咧嘴'}",
#  '🚤': "{'快艇'}",
#  '🧶': "{'毛线'}",
#  '🏍': "{'摩托车'}",
#  '\U0001fa82': "{'降落伞'}",
#  '🛹': "{'滑板'}",
#  '🕵': "{'侦探'}",
#  '🦵': "{'腿'}",
#  '🎻': "{'小提琴'}",
#  '🍈': "{'甜瓜'}",
#  '🦗': "{'蟋蟀'}",
#  '💍': "{'戒指'}",
#  '🧓': "{'老年人'}",
#  '🙂': "{'呵呵'}",
#  '🏤': "{'邮局'}",
#  '\U0001f9ba': "{'救生衣'}",
#  '🏔': "{'雪山'}",
#  '♟︎': "{'兵'}",
#  '⚡': "{'高压'}",
#  '🦳': "{'白发'}",
#  '🌫': "{'雾'}",
#  '🏡': "{'别墅'}",
#  '🦆': "{'鸭子'}",
#  '☹': "{'不满'}",
#  '👮': "{'警察'}",
#  '🧭': "{'指南针'}",
#  '🧜\u200d♀️': "{'美人鱼'}",
#  '♩': "{'四分音符'}",
#  '♆': "{'海王星'}",
#  '🏑': "{'曲棍球'}",
#  '🐁': "{'老鼠'}",
#  '👏': "{'鼓掌'}",
#  '🧜': "{'人鱼'}",
#  '🏇': "{'赛马'}",
#  '👙': "{'比基尼'}",
#  '♨': "{'温泉'}",
#  '🧠': "{'脑'}",
#  '🐜': "{'蚂蚁'}",
#  '💻': "{'笔记本电脑'}",
#  '🎢': "{'过山车'}",
#  '😶': "{'沉默'}",
#  '😭': "{'放声大哭'}",
#  '🧥': "{'外套'}",
#  '⛆': "{'雨'}",
#  '🚆': "{'火车'}",
#  '🤖': "{'机器人'}",
#  '👸': "{'公主'}",
#  '🚢': "{'船'}",
#  '🎲': "{'骰子'}",
#  '🏭': "{'工厂'}",
#  '🦘': "{'袋鼠'}",
#  '❤': "{'红心'}",
#  '🐠': "{'热带鱼'}",
#  '🖨': "{'打印机'}",
#  '🐊': "{'鳄鱼'}",
#  '🙋': "{'举手'}",
#  '🏬': "{'商场'}",
#  '⛺': "{'帐篷'}",
#  '🦲': "{'秃顶'}",
#  '☎': "{'电话'}",
#  '🐕': "{'狗'}",
#  '🧢': "{'鸭舌帽'}",
#  '😀': "{'嘿嘿'}",
#  '💰': "{'钱袋'}",
#  '🥴': "{'头昏眼花'}",
#  '👋': "{'挥手'}",
#  '🏊': "{'游泳'}",
#  '🌿': "{'药草'}",
#  '🖤': "{'黑心'}",
#  '💇': "{'理发'}",
#  '🐙': "{'章鱼'}",
#  '🥕': "{'胡萝卜'}",
#  '📹': "{'摄像机'}",
#  '🔥': "{'火焰'}",
#  '🦋': "{'蝴蝶'}",
#  '🎸': "{'吉他'}",
#  '⛰': "{'山'}",
#  '💿': "{'光盘'}",
#  '🍬': "{'糖'}",
#  '🧙': "{'法师'}",
#  '🧳': "{'行李箱'}",
#  '⛵': "{'帆船'}",
#  '🙍': "{'皱眉'}",
#  '🦍': "{'大猩猩'}",
#  '😰': "{'冷汗'}",
#  '🎾': "{'网球'}",
#  '📽': "{'电影放映机'}",
#  '💷': "{'英镑'}",
#  '🍥': "{'鱼板'}",
#  '⭐': "{'星星'}",
#  '💒': "{'婚礼'}",
#  '👖': "{'牛仔裤'}",
#  '👄': "{'嘴'}",
#  '🍒': "{'樱桃'}",
#  '🏸': "{'羽毛球'}",
#  '🥒': "{'黄瓜'}",
#  '🌲': "{'松树'}",
#  '✍': "{'写字'}",
#  '🌹': "{'玫瑰'}",
#  '♄': "{'土星'}",
#  '🌾': "{'稻子'}",
#  '🌼': "{'开花'}",
#  '🤽': "{'水球'}",
#  '🦎': "{'蜥蜴'}",
#  '🥥': "{'椰子'}",
#  '👨\u200d🌾': "{'农夫'}",
#  '🦛': "{'河马'}",
#  '🗽': "{'自由女神像'}",
#  '🦱': "{'卷发'}",
#  '🥞': "{'烙饼'}",
#  '🖍': "{'蜡笔'}",
#  '😫': "{'累'}",
#  '🥧': "{'派'}",
#  '😅': "{'苦笑'}",
#  '🌷': "{'郁金香'}",
#  '🌅': "{'日出'}",
#  '🥰': "{'喜笑颜开'}",
#  '💤': "{'睡着'}",
#  '🥉': "{'铜牌'}",
#  '🍖': "{'排骨'}",
#  '💁': "{'前台'}",
#  '🍷': "{'葡萄酒'}",
#  '🍞': "{'面包'}",
#  '🍻': "{'干杯'}",
#  '🦡': "{'獾'}",
#  '🐈': "{'猫'}",
#  '💑': "{'情侣'}",
#  '✉': "{'信封'}",
#  '✨': "{'闪亮'}",
#  '💧': "{'水滴'}",
#  '🍽': "{'餐具'}",
#  '🍯': "{'蜂蜜'}",
#  '🐲': "{'龙头'}",
#  '🐤': "{'小鸡'}",
#  '📠': "{'传真机'}",
#  '⛱': "{'阳伞'}",
#  '🦀': "{'蟹'}",
#  '📮': "{'邮筒'}",
#  '♇': "{'冥王星'}",
#  '🛷': "{'雪橇'}",
#  '🕳': "{'洞'}",
#  '⚘': "{'花'}",
#  '👠': "{'高跟鞋'}",
#  '🍼': "{'奶瓶'}",
#  '🍿': "{'爆米花'}",
#  '🍉': "{'西瓜'}",
#  '🏚': "{'废墟'}",
#  '🧂': "{'盐'}",
#  '🛳': "{'客轮'}",
#  '🏅': "{'奖牌'}",
#  '🍩': "{'甜甜圈'}",
#  '👟': "{'跑鞋'}",
#  '📿': "{'念珠'}",
#  '🍐': "{'梨'}",
#  '🧝': "{'小精灵'}",
#  '🏠': "{'房子'}",
#  '💵': "{'美元'}",
#  '🏕': "{'露营'}",
#  '😪': "{'困'}",
#  '🎱': "{'台球'}",
#  '🕊': "{'鸽'}",
#  '🍫': "{'巧克力'}",
#  '🦁': "{'狮子'}",
#  '📦': "{'包裹'}",
#  '🐀': "{'耗子'}",
#  '\U0001fa81': "{'风筝'}",
#  '👩': "{'女人'}",
#  '🍄': "{'蘑菇'}",
#  '👃': "{'鼻子'}",
#  '🛏': "{'床'}",
#  '💆': "{'按摩'}",
#  '🌻': "{'向日葵'}",
#  '📚': "{'书'}",
#  '🦶': "{'脚'}",
#  '🍌': "{'香蕉'}",
#  '👽': "{'外星人'}",
#  '🦃': "{'火鸡'}",
#  '🐏': "{'公羊'}",
#  '💔': "{'心碎'}",
#  '☔': "{'雨伞'}",
#  '🍑': "{'桃'}",
#  '🥭': "{'芒果'}",
#  '☠': "{'骷髅'}",
#  '👺': "{'小妖精'}",
#  '♅': "{'天王星'}",
#  '🧦': "{'袜子'}",
#  '🚁': "{'直升机'}",
#  '😒': "{'不高兴'}",
#  '🤢': "{'恶心'}",
#  '\U0001f9a5': "{'树懒'}",
#  '🐦': "{'鸟'}",
#  '🐐': "{'山羊'}",
#  '🐒': "{'猴子'}",
#  '\U0001f971': "{'打呵欠'}",
#  '⚓': "{'锚'}",
#  '👤': "{'人像'}",
#  '🌘': "{'残月'}",
#  '👴': "{'老爷爷'}",
#  '💫': "{'头晕'}",
#  '♁': "{'地球'}",
#  '🥿': "{'平底鞋'}",
#  '🚜': "{'拖拉机'}",
#  '😵': "{'晕头转向'}",
#  '🚗': "{'汽车'}",
#  '💋': "{'唇印'}",
#  '🥎': "{'垒球'}",
#  '🚀': "{'火箭'}",
#  '🎀': "{'蝴蝶结'}",
#  '🗈': "{'内容'}",
#  '☺': "{'微笑'}",
#  '🤒': "{'发烧'}",
#  '💯': "{'一百分'}",
#  '🀄': "{'红中'}",
#  '🐔': "{'鸡'}",
#  '🏋': "{'举重'}",
#  '🌬': "{'大风'}",
#  '🌭': "{'热狗'}",
#  '🔔': "{'铃铛'}",
#  '🧾': "{'收据'}",
#  '🚠': "{'缆车'}",
#  '\U0001f9aa': "{'牡蛎'}",
#  '🗣': "{'说话'}",
#  '🔦': "{'手电筒'}",
#  '🖴': "{'硬盘'}",
#  '🌸': "{'樱花'}",
#  '🙄': "{'翻白眼'}",
#  '🎵': "{'音符'}",
#  '⛴': "{'渡轮'}",
#  '🎑': "{'赏月'}",
#  '😮': "{'吃惊'}",
#  '😓': "{'汗'}",
#  '💪': "{'肌肉'}",
#  '🥟': "{'饺子'}",
#  '🦚': "{'孔雀'}",
#  '🦇': "{'蝙蝠'}",
#  '🧒': "{'儿童'}",
#  '👩\u200d🌾': "{'农妇'}",
#  '🤕': "{'受伤'}",
#  '🧚': "{'精灵'}",
#  '💂': "{'卫兵'}",
#  '🐿': "{'松鼠'}",
#  '🛔': "{'宝塔'}",
#  '🐗': "{'野猪'}",
#  '🍆': "{'茄子'}",
#  '😟': "{'担心'}",
#  '🎼': "{'乐谱'}",
#  '🐢': "{'龟'}"}

# %%
# 处理emoji_dict词典
pattern = re.compile('{(.*?)}')
for k, v in emoji_dict.items():
    emoji_dict[k] = re.findall(pattern, v)

# %%
def senti_ana(string, stopwords, BosonNLP_dict, Nega_list, degree_dict):
    """
        对文本内容进行情感分析, 返回情感得分
        string: 微博文本内容 str
        stopwords: 停用词 list
        BosonNLP_dict: 情感词典 dict
        Nega_list: 否定词词典 list
        degree_dict: 程度副词词典 dict
        return: score 情感得分
    """
    word_list = jieba_cut(string, stopwords, emoji_dict)  # 对文本内容进行分词

    sen_word = dict()  # 情感词词典 索引为分词结果在word_list中的下标
    nega_word = dict()  # 否定词词典 同上
    degree_word = dict()  # 程度副词词典 同上

    # 对分词结果进行分类
    for i in range(len(word_list)):
        word = word_list[i]
        if word in BosonNLP_dict and word not in Nega_list and word not in degree_dict.keys():
            sen_word[i] = BosonNLP_dict[word]
        elif word in Nega_list and word not in degree_dict.keys():
            nega_word[i] = -1
        elif word in degree_dict.keys():
            degree_word[i] = degree_dict[word]

    # 计算得分
    score = 0  # 初始得分为0
    weight = 1  # 初始权重为1
    sen_index = -1  # 初始情感词索引为-1
    sen_index_list = list(sen_word.keys())  # 情感词索引列表

    for i in range(len(word_list)):
        if i in sen_word.keys():
            score += weight*float(sen_word[i])
            sen_index += 1
            if sen_index < len(sen_index_list)-1:
                for j in range(sen_index_list[sen_index], sen_index_list[sen_index+1]):
                    # 如果两相邻情感词之间有否定词
                    if j in nega_word.keys():
                        weight = -weight
                    # 如果两相邻情感词之间有程度副词
                    elif j in degree_word.keys():
                        weight *= float(degree_word[j])
            if sen_index < len(sen_index_list)-1:
                i = sen_index_list[sen_index+1]

    return score  # 返回情感得分

# %%
scorelist=[]

# %%
for i in content:
    score=senti_ana(i,stopwords,BosonNLP_dict,Nega_list,degree_dict)
    scorelist.append(score)

# %%
scorelist
# Out:
# [-1.135763976946,
#  30.602560582269806,
#  4.5173920744908,
#  3.8686835700503006,
#  7.414674054577999,
#  2.25384130479,
#  8.660106955145,
#  1.462636277784,
#  -1.0454766696545004,
#  -6.6631419541664005,
#  -13.527011818393001,
#  9.796449948599,
#  14.915809818248997,
#  1.145660809559,
#  8.88966867245,
#  -2.29324480176777,
#  -3.09685785465035,
#  3.73739167021,
#  4.8042289509554,
#  -1.162493158958,
#  2.4286209497855005,
#  -0.471869645084,
#  -3.8297721235413,
#  -7.5982470021345,
#  -3.7644088901362,
#  0.16561660161299985,
#  2.749019770253,
#  -2.9141022840368,
#  0.7674950737590001,
#  -0.6381741959236,
#  0,
#  1.7565519562695,
#  -6.021281124096,
#  -4.517876423582,
#  0.238138860445,
#  -0.9884442060366698,
#  -0.9491350766440001,
#  0.475396905266,
#  1.182219424647,
#  -0.19383707691500018,
#  0.3399235669108,
#  -3.9181656053269998,
#  0.297887116711,
#  6.442784656269998,
#  1.3791769032240002,
#  3.84296452259,
#  0,
#  0,
#  -1.26012141149,
#  3.73739167021,
#  -1.3100386763126002,
#  18.989660783101,
#  20.939836826729998,
#  2.9393605944,
#  3.602202084702,
#  -0.40603912682800014,
#  -1.27710271895,
#  2.27982037099,
#  1.5048974747840003,
#  0.5558636692310002,
#  0.4988316619630002,
#  3.850940543742,
#  2.07822211153,
#  -3.4360666555967003,
#  -0.48857911534306,
#  0.1469939176170001,
#  1.4337584616009997,
#  -0.22185077341900006,
#  -2.1575728194929997,
#  -1.128788375027,
#  -3.7726352304469994]

# %%
len(scorelist)
# Out:
# 71

# %%
for i in range(0,len(scorelist)):
    if scorelist[i] == 0:
        print(scorelist[i])
        print(content[i])
# Out:
# 0
# 我也开始了  原图
# 0
# 好闲啊。  原图
# 0
# 转发理由:新年快乐！多夸夸自己！

# %%
result_headers = ['微博id', '微博正文/转发理由', '是否原创', '情感得分']
with open('lfq_csv.csv', 'r', encoding='utf-8') as f:
    reader=csv.reader(f)
    content = [row[:]for row in reader][1:]

# %%
content
# Out:
# [['J61JpuIB4', '复习期末的这几天，我从钻五到了钻一。 \xa0', 'True'],
#  ['J61Eck4cB',
#   '转发理由:恭喜@-席瑾- 1名用户获得【1k】。微博官方唯一抽奖工具@微博抽奖平台 对本次抽奖进行监督，结果公正有效。公示链接：微博抽奖平台 //@_老番茄_:庆祝吃鸡，转发抽1k！明天20点开奖！ 查看图片\xa0\xa0',
#   'False'],
#  ['J5PbLfDL4', '转发理由:庆祝吃鸡，转发抽1k！明天20点开奖！ 查看图片\xa0\xa0', 'False'],
#  ['J5InF2nQB', '又到了一年两度，万众期待的考前临时抱佛脚时间 \xa0', 'True'],
#  ['J5dfz4Aer', '默契挑战！看看我和BOY谁才是真正的好兄弟#YSL212#  _老番茄_的微博视频 \xa0', 'True'],
#  ['J4PiG9jQv', '生日快乐，我的偶像 _老番茄_的微博视频 \xa0', 'True'],
#  ['J4FBYipCS', '儿童节快乐！希望我的脸能变回小时候那么圆润！ \xa0原图\xa0', 'True'],
#  ['J4wyYePK4', '失去梦想变成大鸡腿 \xa0原图\xa0', 'True'],
#  ['J4dd11Eu9',
#   '决定利用每天上课开小差的时间学一点蒙语。如果下次回内蒙能看懂蒙文了，说明我这学期一定开了很多小差。 \xa0原图\xa0',
#   'True'],
#  ['J3isW0rI4', '为什么b站在我要交作业之前上线柯南剧场版。可恶，已经看了一天柯南了。 \xa0', 'True'],
#  ['J2xp6awdt',
#   '昨晚失眠睡不着，翻来覆去。四点钟的时候，突然悟到，好像是热得睡不着。于是毅然打开了空调，立马睡着了。 \xa0',
#   'True'],
#  ['J24SoEtY3',
#   '转发理由:给我的好弟弟打call 查看图片 //@最强大脑陆英泽:#最强大脑开播##最强大脑#还有半小时就要开播拉，看不了电视的也可以访问http://t.cn/heFOA收看网络直播\xa0\xa0',
#   'False'],
#  ['J21Fu3W9u',
#   '完美还原世界名画！你说我画挑战。天猫搜索OPPO官方旗舰店get同款耳机  _老番茄_的微博视频 \xa0',
#   'True'],
#  ['J1MEqeim1', '藏在黑影中的小怪兽 _老番茄_的微博视频 \xa0', 'True'],
#  ['J18ST6C1n',
#   '感谢@腾讯NintendoSwitch 送的国行switch和李维斯联名小夹克儿！耀西真可爱 \xa0[组图共3张]\xa0原图\xa0',
#   'True'],
#  ['J0Sk0s863', '打算做视频之前休息一会→看一眼直播→看到有人在玩奥特曼游戏→勾起回忆→看了一整晚的奥特曼 \xa0', 'True'],
#  ['J0yiq4que', '如何让脸看上去不那么长：强行遮住下巴 \xa0原图\xa0', 'True'],
#  ['IFLa17HLW', '分享图片 \xa0原图\xa0', 'True'],
#  ['IFJi17U1F',
#   '第一次网课考试，真是有趣的体验。每当抓耳挠腮做不出来的时候，切到会议室，发现同学们也在抓耳挠腮，我就放心了。 \xa0',
#   'True'],
#  ['IFrvR5s3S', '还有一天就考试了！开启临时抱佛脚模式！ \xa0', 'True'],
#  ['IEGD7qF6t',
#   '#世界读书日# 推荐一下《围城》吧，特有意思。高中看的，大学时出门还经常揣着在飞机上重温（虽然最后都睡着了） \xa0',
#   'True'],
#  ['IEe5Tcmgr', '“猫” \xa0原图\xa0', 'True'],
#  ['IDVvFlsIp', '最近不知道为啥，总感觉提不起劲，很累，明明也没有很忙。是不是我的内心太想返校上学了。 \xa0', 'True'],
#  ['ID0vf6o9V', '走到半路下暴雨了，现在是一只瑟瑟发抖的落汤鸡 \xa0', 'True'],
#  ['ICRH9yVqC', '下课了。明天早上还要起来上课。头发渐渐消失。 \xa0', 'True'],
#  ['IC5HDmsgG', '他感动的快要哭了。 _老番茄_的微博视频 \xa0', 'True'],
#  ['IBEr6yiAZ', '转发理由:致敬，缅怀。\xa0\xa0', 'False'],
#  ['IBmMJ84tw', '总算做完视频和封面了，但是明天还有早课和作业🙉🙉🙉头发要掉光了！ \xa0原图\xa0', 'True'],
#  ['IATPYsQaZ', '不知道为什么，看到这只就想笑 \xa0原图\xa0', 'True'],
#  ['IArWXyPJo', '这周有个四个作业要交（还没开始），如果活过这周，我一定好好做视频 \xa0', 'True'],
#  ['IA9d824l0', '我也开始了 \xa0原图\xa0', 'True'],
#  ['IznreEWp4', '最近外卖点太多了。外卖小哥对我的称呼已经从“张先生”变成了“张哥”，现在是“小张”了。 \xa0', 'True'],
#  ['IyCF2ojMN', '最近天天失眠，所以今天决定睡前做点作业，帮助自己尽快入眠 \xa0', 'True'],
#  ['IyjCEuKjM', '晚睡→艰难早起上课→补觉到傍晚→晕乎乎地摸鱼→因为补了觉睡不着→晚睡。 \xa0原图\xa0', 'True'],
#  ['IxdDega6Z', '小狗为何愁容满面 \xa0原图\xa0', 'True'],
#  ['IwHHi1DE0', '谁能想到，正式开始上网课前一天晚上，我通宵玩了一晚上扫雷。 \xa0', 'True'],
#  ['Iwutv3rHJ', '宅在家有什么能拍的生活区视频吗，想不出来！ \xa0', 'True'],
#  ['Iwa4sedea', '理完发了，终于重见光明了。 \xa0原图\xa0', 'True'],
#  ['IvzSdtNuN', '我被黑猫警长抓捕了 \xa0原图\xa0', 'True'],
#  ['Iv5OoAJBY', '涂润唇膏的时候吃了一口，真难吃，我再也不吃润唇膏了。 \xa0', 'True'],
#  ['IuEgh7OuF', '明天要开始上网课了，有缘再见 \xa0', 'True'],
#  ['IubJpzwru', '不小心买多了，不得不天天啃草，一天啃两顿草 _老番茄_的微博视频 \xa0', 'True'],
#  ['Iu3BNgfc3', '人类的本质 \xa0[组图共2张]\xa0原图\xa0', 'True'],
#  ['ItIXHEZ6R', '很懒，但又要保证膳食均衡，于是买了一冰箱的黄瓜，现在没事就啃黄瓜，快变成黄瓜人了。 \xa0', 'True'],
#  ['IsY6rBaUz', '年前忘了去理发的我，现在已经得夹发卡才看得见东西了 \xa0', 'True'],
#  ['Isxkk4R0p', '真没想到我竟然更新了，真不赖 \xa0', 'True'],
#  ['Is3TeiI0U', '好闲啊。 \xa0原图\xa0', 'True'],
#  ['Ir7t3sj0G', '转发理由:新年快乐！多夸夸自己！\xa0\xa0', 'False'],
#  ['Ir1BuaTF4', '退烧了。新年快乐，一切顺意！最重要的是身体健康！ \xa0', 'True'],
#  ['IqQbQ3uEJ', '分享图片 \xa0原图\xa0', 'True'],
#  ['IqMWOdToC',
#   '从百大回来就一直在发烧，怕传染给别人所以一直把自己关在家里。原定要在春节发的视频做不出来了，非常对不起期待我更新的观众们。好在血氧一直维持在96-97，也没有出现呼吸困难。大家要好好注意身体呀，我继续去瘫着了。 \xa0',
#   'True'],
#  ['Iqers5sM8',
#   '转发理由:我我我，我。。//@复旦大学:让我康康到底是谁家的排面//@上海财经大学:财大排面！老番茄冲！//@哔哩哔哩智能姬:#B站百大UP主#揭晓！快来看看都有谁~~来为喜欢的UP主加油呀！\xa0\xa0',
#   'False'],
#  ['IqbwKqyuf',
#   '转发理由:🙊懵了！谢谢财大！//@上海财经大学:财大排面！老番茄冲！//@哔哩哔哩智能姬:#B站百大UP主#揭晓！快来看看都有谁~~来为喜欢的UP主加油呀！\xa0\xa0',
#   'False'],
#  ['Iq6obuD8D', '谢谢大家，我太紧张了 \xa0原图\xa0', 'True'],
#  ['IpNdL5CJh', '哈哈哈哈百大的照片拍的像食人魔 \xa0原图\xa0', 'True'],
#  ['Ipt66AncK', '为期两天的寒假小学期结束了！我又放假了！ \xa0原图\xa0', 'True'],
#  ['Ipg9OBd2V', '我又开学啦，哈哈哈哈 \xa0原图\xa0', 'True'],
#  ['Ip1sn0GJP', '我和沼王烛光晚餐🕯🕯 \xa0原图\xa0', 'True'],
#  ['IoHu3DtBQ', '马上最后一门了大家期末加油，我玩会手机。 \xa0', 'True'],
#  ['IofgkfyJO',
#   '今天去拍照，我问发型师，我是不是发际线高。她说，不高不高，因为你脸很长，才显得高。我一时不知道是该笑该哭。 \xa0',
#   'True'],
#  ['InY7Z6aIy', '已经好久没在理发店听到“小伙头发挺厚”的夸奖了 \xa0原图\xa0', 'True'],
#  ['InDLxpoz3', '看了看年度总结。为什么最多的弹幕是泪目啊哈哈哈哈哈哈哈 \xa0[组图共3张]\xa0原图\xa0', 'True'],
#  ['Inn0ypEUw', '2020，我来啦！！ \xa0[组图共4张]\xa0原图\xa0', 'True'],
#  ['In2URlSO8', '又到了每学期期末的焦虑时间 \xa0', 'True'],
#  ['ImAPQqgAc', '给茄酱找了个男朋友 \xa0原图\xa0', 'True'],
#  ['Im9RkxLSL', '经过一学期的学习，我的编程水平如图。 \xa0原图\xa0', 'True'],
#  ['IlHpQCgmu', '考研加油！吃好睡好！ \xa0原图\xa0', 'True'],
#  ['IlobHuwDm', '冷冷的冰雨在茄上胡乱的拍 \xa0原图\xa0', 'True'],
#  ['Il4tNcSe6', '得了一下雨就不想上学的怪病 \xa0原图\xa0', 'True'],
#  ['IkMyV1ebQ', '这个狗仿佛在喂奶。 \xa0原图\xa0', 'True'],
#  ['IksNetbKH', '奇怪，明明什么都没记住一学期就过去了 \xa0原图\xa0', 'True']]

# %%
scorelist
# Out:
# [-1.135763976946,
#  30.602560582269806,
#  4.5173920744908,
#  3.8686835700503006,
#  7.414674054577999,
#  2.25384130479,
#  8.660106955145,
#  1.462636277784,
#  -1.0454766696545004,
#  -6.6631419541664005,
#  -13.527011818393001,
#  9.796449948599,
#  14.915809818248997,
#  1.145660809559,
#  8.88966867245,
#  -2.29324480176777,
#  -3.09685785465035,
#  3.73739167021,
#  4.8042289509554,
#  -1.162493158958,
#  2.4286209497855005,
#  -0.471869645084,
#  -3.8297721235413,
#  -7.5982470021345,
#  -3.7644088901362,
#  0.16561660161299985,
#  2.749019770253,
#  -2.9141022840368,
#  0.7674950737590001,
#  -0.6381741959236,
#  0,
#  1.7565519562695,
#  -6.021281124096,
#  -4.517876423582,
#  0.238138860445,
#  -0.9884442060366698,
#  -0.9491350766440001,
#  0.475396905266,
#  1.182219424647,
#  -0.19383707691500018,
#  0.3399235669108,
#  -3.9181656053269998,
#  0.297887116711,
#  6.442784656269998,
#  1.3791769032240002,
#  3.84296452259,
#  0,
#  0,
#  -1.26012141149,
#  3.73739167021,
#  -1.3100386763126002,
#  18.989660783101,
#  20.939836826729998,
#  2.9393605944,
#  3.602202084702,
#  -0.40603912682800014,
#  -1.27710271895,
#  2.27982037099,
#  1.5048974747840003,
#  0.5558636692310002,
#  0.4988316619630002,
#  3.850940543742,
#  2.07822211153,
#  -3.4360666555967003,
#  -0.48857911534306,
#  0.1469939176170001,
#  1.4337584616009997,
#  -0.22185077341900006,
#  -2.1575728194929997,
#  -1.128788375027,
#  -3.7726352304469994]

# %%
all_filename = 'lfq_with_score.csv'

def write_csv(filename):
    try:
        result_headers = ['微博id', '微博正文/转发理由', '是否原创', '情感得分']
        with open('lfq_csv.csv', 'r', encoding='utf-8') as f:
            reader=csv.reader(f)
            content = [row[:]for row in reader][1:]
        
        for i in range(0,len(content)):
            content[i].append(scorelist[i])

        with open(filename, 'a', encoding='utf-8-sig', newline='') as f:
            writer = csv.writer(f)
            writer.writerows([result_headers])
            writer.writerows(content)
        
    except Exception as e:
        print(e)

# %%
write_csv(all_filename)
