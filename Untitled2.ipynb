# %%
import requests
import re
import time
from bs4 import BeautifulSoup
from lxml import etree

# %%
url='https://hanyucidian.18dao.cn/emoji?page=1'
headers={'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36'}

# %%
r=requests.get(url,headers=headers)

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<html lang="zh-hans" dir="ltr"\n>\n\n<head>\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<meta name="Generator" content="Drupal 7 (http://drupal.org)" />\n<link rel="shortcut icon" href="https://hanyucidian.18dao.cn/sites/default/files/favicon.ico" type="image/vnd.microsoft.icon" />\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n    <meta name="MobileOptimized" content="width" />\n    <meta name="HandheldFriendly" content="true" />\n    <meta name="viewport" content="width=device-width, initial-scale=1.0" />\n    <meta http-equiv="cleartype" content="on" />\n\t<link rel="apple-touch-icon" href="/apple-touch-icon.png" />\n<link rel="amphtml" href="https://hanyucidian.18dao.cn/emoji?amp=&page=1" />\n<link rel="miphtml" href="https://hanyucidian.18dao.cn/emoji?mip=&page=1" />\n<link rel="alternate" hreflang="zh-hans" href="https://hanyucidian.18dao.cn/emoji?page=1" />\n<link rel="alternate" hreflang="zh-hant" href="https://hanyucidian.18dao.cn/zh-hant/emoji?page=1" />\n\t<script src="//msite.baidu.com/sdk/c.js?appid=1575964242903510"></script>\n  <title>汉语词典Emoji对照表 | 一把刀 《汉语词典》📕</title>\n  <link type="text/css" rel="stylesheet" href="https://hanyucidian.18dao.cn/sites/hanyucidian.18dao.cn/files/css/css_xE-rWrJf-fncB6ztZfd2huxqgxu4WO-qwma6Xer30m4.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://hanyucidian.18dao.cn/sites/hanyucidian.18dao.cn/files/css/css_TsVRTbLFUpEZAfw-_bWPJu840QT523CPjUVJ5MRWfyk.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://hanyucidian.18dao.cn/sites/hanyucidian.18dao.cn/files/css/css_MbYnMoJg5shLBLS7odQBqlv2NMMchIG6ZA0SY_wwPy0.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://hanyucidian.18dao.cn/sites/hanyucidian.18dao.cn/files/css/css_9BKYkw0EEpoJLmx-qBC_PwWo1cUCMd-ynFnkICMMnzk.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://hanyucidian.18dao.cn/sites/hanyucidian.18dao.cn/files/css/css_2THG1eGiBIizsWFeexsNe1iDifJ00QRS9uSd03rY9co.css" media="print" />\n  <script type="text/javascript" src="https://hanyucidian.18dao.cn/sites/hanyucidian.18dao.cn/files/js/js_h8Od-FAGkhR_7A30HaaMaTrO_5Hale-5uw8QHV7ogq0.js"></script>\n<script type="text/javascript" src="https://hanyucidian.18dao.cn/sites/hanyucidian.18dao.cn/files/js/js_wqsUZ3oERhOWhNe8ASglQWUn-l5sYPqk4ugkN-a7Q3U.js"></script>\n<script type="text/javascript" src="https://hanyucidian.18dao.cn/sites/hanyucidian.18dao.cn/files/js/js_rp1WDXwa4WvjAKQcxPlbSq-d1PjKArc2P2L6lhx-81I.js"></script>\n<script type="text/javascript">\n<!--//--><![CDATA[//><!--\njQuery.extend(Drupal.settings, {"basePath":"\\/","pathPrefix":"","ajaxPageState":{"theme":"responsive_bartik","theme_token":"LuzaAEQCHRiG-aHM9Up8sQTqqjXvUi4TrFt8KpTmIQ0","js":{"0":1,"sites\\/all\\/modules\\/jquery_update\\/replace\\/jquery\\/1.10\\/jquery.min.js":1,"misc\\/jquery-extend-3.4.0.js":1,"misc\\/jquery-html-prefilter-3.5.0-backport.js":1,"misc\\/jquery.once.js":1,"misc\\/drupal.js":1,"sites\\/all\\/libraries\\/ueditor\\/third-party\\/SyntaxHighlighter\\/shCore.js":1,"public:\\/\\/languages\\/zh-hans_iTtO3eVLewPB5KTA-pZ324vkWitFIqDWL2BkhPxAjjA.js":1,"sites\\/all\\/themes\\/responsive_bartik\\/js\\/collapsible-menu.js":1,"sites\\/all\\/themes\\/responsive_bartik\\/js\\/stickUp.min.js":1},"css":{"modules\\/system\\/system.base.css":1,"modules\\/system\\/system.menus.css":1,"modules\\/system\\/system.messages.css":1,"modules\\/system\\/system.theme.css":1,"modules\\/comment\\/comment.css":1,"modules\\/field\\/theme\\/field.css":1,"modules\\/node\\/node.css":1,"modules\\/search\\/search.css":1,"modules\\/user\\/user.css":1,"sites\\/all\\/modules\\/views\\/css\\/views.css":1,"sites\\/all\\/modules\\/ctools\\/css\\/ctools.css":1,"sites\\/all\\/libraries\\/ueditor\\/third-party\\/SyntaxHighlighter\\/shCoreDefault.css":1,"modules\\/locale\\/locale.css":1,"sites\\/all\\/themes\\/responsive_bartik\\/css\\/layout.css":1,"sites\\/all\\/themes\\/responsi ...

# %%
r.raise_for_status
# Out:
# <bound method Response.raise_for_status of <Response [200]>>

# %%
r.status_code
# Out:
# 200

# %%
html=r.text

# %%
soup=BeautifulSoup(html,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="zh-hans">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="Drupal 7 (http://drupal.org)" name="Generator"/>
#   <link href="https://hanyucidian.18dao.cn/sites/default/files/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width" name="MobileOptimized">
#    <meta content="true" name="HandheldFriendly"/>
#    <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#    <meta content="on" http-equiv="cleartype"/>
#    <link href="/apple-touch-icon.png" rel="apple-touch-icon"/>
#    <link href="https://hanyucidian.18dao.cn/emoji?amp=&amp;page=1" rel="amphtml"/>
#    <link href="https://hanyucidian.18dao.cn/emoji?mip=&amp;page=1" rel="miphtml"/>
#    <link href="https://hanyucidian.18dao.cn/emoji?page=1" hreflang="zh-hans" rel="alternate"/>
#    <link href="https://hanyucidian.18dao.cn/zh-hant/emoji?page=1" hreflang="zh-hant" rel="alternate"/>
#    <script src="//msite.baidu.com/sdk/c.js?appid=1575964242903510">
#    </script>
#    <title>
#     汉语词典Emoji对照表 | 一把刀 《汉语词典》📕
#    </title>
#    <link href="https://hanyucidian.18dao.cn/sites/hanyucidian.18dao.cn/files/css/css_xE-rWrJf-fncB6ztZfd2huxqgxu4WO-qwma6Xer30m4.css" media="all" rel="stylesheet" type="text/css"/>
#    <link href="https://hanyucidian.18dao.cn/sites/hanyucidian.18dao.cn/files/css/css_TsVRTbLFUpEZAfw-_bWPJu840QT523CPjUVJ5MRWfyk.css" media="all" rel="stylesheet" type="text/css"/>
#    <link href="https://hanyucidian.18dao.cn/sites/hanyucidian.18dao.cn/files/css/css_MbYnMoJg5shLBLS7odQBqlv2NMMchIG6ZA0SY_wwPy0.css" media="all" rel="stylesheet" type="text/css"/>
#    <link href="https://hanyucidian.18dao.cn/sites/hanyucidian.18dao.cn/files/css/css_9BKYkw0EEpoJLmx-qBC_PwWo1cUCMd-ynFnkICMMnzk.css" media="all" rel="stylesheet" type="text/css"/>
#    <link href="https://hanyucidian.18dao.cn/sites/hanyucidian.18dao.cn/files/css/css_2THG1eGiBIizsWFeexsNe1iDifJ00QRS9uSd03rY9co.css" media="print" rel="stylesheet" type="text/css"/>
#    <script src="https://hanyucidian.18dao.cn/sites/hanyucidian.18dao.cn/files/js/js_h8Od-FAGkhR_7A30HaaMaTrO_5Hale-5uw8QHV7ogq0.js" type="text/javascript">
#    </script>
#    <script src="https://hanyucidian.18dao.cn/sites/hanyucidian.18dao.cn/files/js/js_wqsUZ3oERhOWhNe8ASglQWUn-l5sYPqk4ugkN-a7Q3U.js" type="text/javascript">
#    </script>
#    <script src="https://hanyucidian.18dao.cn/sites/hanyucidian.18dao.cn/files/js/js_rp1WDXwa4WvjAKQcxPlbSq-d1PjKArc2P2L6lhx-81I.js" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"responsive_bartik","theme_token":"LuzaAEQCHRiG-aHM9Up8sQTqqjXvUi4TrFt8KpTmIQ0","js":{"0":1,"sites\/all\/modules\/jquery_update\/replace\/jquery\/1.10\/jquery.min.js":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery-html-prefilter-3.5.0-backport.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/libraries\/ueditor\/third-party\/SyntaxHighlighter\/shCore.js":1,"public:\/\/languages\/zh-hans_iTtO3eVLewPB5KTA-pZ324vkWitFIqDWL2BkhPxAjjA.js":1,"sites\/all\/themes\/responsive_bartik\/js\/collapsible-menu.js":1,"sites\/all\/themes\/responsive_bartik\/js\/stickUp.min.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"modules\/comment\/comment.css":1,"modules\/field\/theme\/field.css":1,"modules\/node\/node.css":1,"modules\/search\/search.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/views\/css\/views.css":1,"sites\/all\/modules\/ctools\/css\/ctools.css":1,"sites\/all\/libraries\/ueditor\/third-party\/SyntaxHighlighter\/shCoreDefault.css":1,"modules\/locale\/locale.css":1,"sites\/all\/themes\/responsive_bartik\/css\/layout.css":1,"sites\/all\/themes\/responsive_bartik\/css\/style.css":1,"sites\/all\/themes\/responsive_bartik\/css\/colors.css":1,"sites\/all\/themes\/responsive_bartik\/css\/print.css":1}}});
# //--><!]]>
#    </script>
#    <!--[if (gte IE 6)&(lte IE 8)]>
#     <script src="/sites/all/themes/responsive_bartik/js/selectivizr-min.js"></script>
#   <![endif]-->
#    <!--[if lt IE 9]>
#     <script src="/sites/all/themes/responsive_bartik/js/html5-respond.js"></script>
#   <![endif]-->
#    <!-- baidu tongji start -->
#    <script>
#     var _hmt = _hmt || [];
# (function() {
#   var hm = document.createElement("script");
#   hm.src = "https://hm.baidu.com/hm.js?e80a07a1268e9f66c21a006fbf2991d4";
#   var s = document.getElementsByTagName("script")[0];
#   s.parentNode.insertBefore(hm, s);
# })();
#    </script>
#    <!-- baidu tongji end -->
#    <!-- google analytics start -->
#    <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-241337-79', 'auto');
#   ga('send', 'pageview');
#    </script>
#    <!-- google analytics end -->
#    <!-------低版本audio兼容----------->
#    <script>
#     var userAgent = navigator.userAgent;
#       console.log(userAgent);
#       var isIE=userAgent.indexOf("compatible") > -1;
# 		console.log(isIE);
#       if(isIE){
#         var reIE = new RegExp("MSIE (\\d+\\.\\d+);");
#         reIE.test(userAgent);
#         var fIEVersion = parseFloat(RegExp["$1"]);
# 		console.log(fIEVersion);
# 		console.log(123);
#         if(fIEVersion<=9){
# 				var head=document.getElementsByTagName('head')[0];
# 				 var fileref = document.createElement('script');
# 				 console.log(fileref);
# 				fileref.setAttribute("type", "text/javascript");
# 				fileref.setAttribute("src", "http://api.html5media.info/1.1.6/html5media.min.js");
# 				head.appendChild(fileref);
#       }else{
#           console.log("IE版本高于9");
#         }
#       }else{
#       console.log("这不是IE浏览器")
#       }
#    </script>
#    <!-- adsense page level ads start -->
#    <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#    </script>
#    <script>
#     (adsbygoogle = window.adsbygoogle || []).push({
#     google_ad_client: "ca-pub-8670212889350560",
#     enable_page_level_ads: true
#   });
#    </script>
#    <!-- adsense page level ads end -->
#   </meta>
#  </head>
#  <body class="html not-front not-logged-in one-sidebar sidebar-first page-emoji">
#   <!-- baidu js push start -->
#   <script>
#    (function(){
#     var bp = document.createElement('script');
#     var curProtocol = window.location.protocol.split(':')[0];
#     if (curProtocol === 'https'){
#    bp.src = 'https://zz.bdstatic.com/linksubmit/push.js';
#   }
#   else{
#   bp.src = 'http://push.zhanzhang.baidu.com/push.js';
#   }
#     var s = document.getElementsByTagName("script")[0];
#     s.parentNode.insertBefore(bp, s);
# })();
#   </script>
#   <!-- baidu js push end -->
#   <div id="skip-link">
#    <a class="element-invisible element-focusable" href="#main-content">
#     跳转到主要内容
#    </a>
#   </div>
#   <div id="page-wrapper">
#    <div id="page">
#     <header class="without-secondary-menu" id="header" role="banner">
#      <div class="section clearfix">
#       <a href="/" id="logo" rel="home" title="首页">
#        <img alt="首页" src="https://hanyucidian.18dao.cn/sites/default/files/logo.png"/>
#       </a>
#       <div id="name-and-slogan">
#        <div id="site-name">
#         <strong>
#          <a href="/" rel="home" title="首页">
#           <span>
#            一把刀 《汉语词典》📕
#           </span>
#          </a>
#         </strong>
#        </div>
#       </div>
#       <!-- /#name-and-slogan -->
#       <div class="region region-header">
#        <div class="block block-block" id="block-block-1">
#         <div class="content">
#          <form action="/search_redirect" method="get">
#           <input name="keyword" placeholder="汉字/中文词 ..." type="text"/>
#           <input type="submit" value="搜索"/>
#          </form>
#         </div>
#         <!-- Baidu Union 18dao.cn Top PC 468x15 Jinjie 2019 -->
#         <div class="page-header-ad">
#          <script src="//d1.18dao.cn/production/static/qvm1xn.js?rmele=noio" type="text/javascript">
#          </script>
#         </div>
#        </div>
#       </div>
#       <nav class="navigation" id="main-menu" role="navigation">
#        <h2 class="element-invisible">
#         主菜单
#        </h2>
#        <ul class="links clearfix" id="main-menu-links">
#         <li class="menu-238 first">
#          <a href="/">
#           首页
#          </a>
#         </li>
#         <li class="menu-483">
#          <a href="/shouzi-liebiao">
#           首字
#          </a>
#         </li>
#         <li class="menu-479">
#          <a href="/liebiao">
#           列表
#          </a>
#         </li>
#         <li class="menu-533">
#          <a href="/node/157669">
#           词典附录
#          </a>
#         </li>
#         <li class="menu-545 active-trail last active">
#          <a class="active-trail active" href="/emoji">
#           Emoji
#          </a>
#         </li>
#        </ul>
#       </nav>
#       <!-- /#main-menu -->
#      </div>
#     </header>
#     <!-- /.section, /#header -->
#     <div class="clearfix" id="main-wrapper">
#      <div class="clearfix" id="main" role="main">
#       <h2 class="element-invisible">
#        当前位置
#       </h2>
#       <div class="breadcrumb" itemscope="" itemtype="http://schema.org/BreadcrumbList">
#        <span itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#         <a href="/" itemprop="item">
#          <span itemprop="name">
#           首页
#          </span>
#         </a>
#         <meta content="1" itemprop="position"/>
#        </span>
#       </div>
#       <div class="column" id="content">
#        <div class="section">
#         <a id="main-content">
#         </a>
#         <h1 class="title" id="page-title">
#          汉语词典Emoji对照表
#         </h1>
#         <div class="tabs">
#         </div>
#         <!-- 反采集程序 -->
#         <div class="region region-content">
#          <div class="block block-system" id="block-system-main">
#           <div class="content">
#            <div class="view view-emoji view-id-emoji view-display-id-page view-dom-id-c582d2e55723d5ac15fe45d6f2796bde">
#             <div class="view-header">
#              <ul>
#               <li>
#                <a href="/emoji">
#                 汉语词典Emoji对照表
#                </a>
#               </li>
#               <li>
#                <a href="/emoji1">
#                 汉语字词翻译Emoji对照表
#                </a>
#               </li>
#              </ul>
#             </div>
#             <div class="view-content">
#              <table class="views-table cols-3">
#               <thead>
#                <tr>
#                 <th class="views-field views-field-counter" scope="col">
#                  序号
#                 </th>
#                 <th class="views-field views-field-title" scope="col">
#                  标题
#                 </th>
#                 <th class="views-field views-field-field-emoji" scope="col">
#                  Emoji
#                 </th>
#                </tr>
#               </thead>
#               <tbody>
#                <tr class="odd views-row-first">
#                 <td class="views-field views-field-counter">
#                  101
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E6%8C%AA%E5%A8%81">
#                   挪威
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇳🇴" title="表示“挪威”的Emoji表情符号：🇳🇴">
#                   🇳🇴
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  102
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%B0%BC%E6%B3%8A%E5%B0%94">
#                   尼泊尔
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇳🇵" title="表示“尼泊尔”的Emoji表情符号：🇳🇵">
#                   🇳🇵
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  103
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%B0%BC%E6%B3%8A%E5%B0%94%E7%8E%8B%E5%9B%BD">
#                   尼泊尔王国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇳🇵" title="表示“尼泊尔王国”的Emoji表情符号：🇳🇵">
#                   🇳🇵
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  104
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E8%8D%B7%E5%85%B0">
#                   荷兰
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇳🇱" title="表示“荷兰”的Emoji表情符号：🇳🇱">
#                   🇳🇱
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  105
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%B0%BC%E5%8A%A0%E6%8B%89%E7%93%9C">
#                   尼加拉瓜
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇳🇮" title="表示“尼加拉瓜”的Emoji表情符号：🇳🇮">
#                   🇳🇮
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  106
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E7%BA%B3%E7%B1%B3%E6%AF%94%E4%BA%9A%E5%85%B1%E5%92%8C%E5%9B%BD">
#                   纳米比亚共和国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇳🇦" title="表示“纳米比亚共和国”的Emoji表情符号：🇳🇦">
#                   🇳🇦
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  107
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E9%A9%AC%E6%9D%A5%E8%A5%BF%E4%BA%9A">
#                   马来西亚
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇲🇾" title="表示“马来西亚”的Emoji表情符号：🇲🇾">
#                   🇲🇾
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  108
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E8%8E%AB%E6%A1%91%E6%AF%94%E5%85%8B">
#                   莫桑比克
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇲🇿" title="表示“莫桑比克”的Emoji表情符号：🇲🇿">
#                   🇲🇿
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  109
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%A2%A8%E8%A5%BF%E5%93%A5">
#                   墨西哥
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇲🇽" title="表示“墨西哥”的Emoji表情符号：🇲🇽">
#                   🇲🇽
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  110
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E9%A9%AC%E8%80%B3%E4%BB%96">
#                   马耳他
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇲🇹" title="表示“马耳他”的Emoji表情符号：🇲🇹">
#                   🇲🇹
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  111
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E6%BE%B3%E9%97%A8">
#                   澳门
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇲🇴" title="表示“澳门”的Emoji表情符号：🇲🇴">
#                   🇲🇴
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  112
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%A4%96%E8%92%99%E5%8F%A4">
#                   外蒙古
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇲🇳" title="表示“外蒙古”的Emoji表情符号：🇲🇳">
#                   🇲🇳
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  113
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E7%BC%85%E7%94%B8">
#                   缅甸
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇲🇲" title="表示“缅甸”的Emoji表情符号：🇲🇲">
#                   🇲🇲
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  114
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E9%A9%AC%E5%88%A9%E5%85%B1%E5%92%8C%E5%9B%BD">
#                   马利共和国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇲🇱" title="表示“马利共和国”的Emoji表情符号：🇲🇱">
#                   🇲🇱
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  115
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E9%A9%AC%E8%BE%BE%E5%8A%A0%E6%96%AF%E5%8A%A0">
#                   马达加斯加
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇲🇬" title="表示“马达加斯加”的Emoji表情符号：🇲🇬">
#                   🇲🇬
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  116
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E9%A9%AC%E5%85%B6%E9%A1%BF%E7%8E%8B%E5%9B%BD">
#                   马其顿王国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇲🇰" title="表示“马其顿王国”的Emoji表情符号：🇲🇰">
#                   🇲🇰
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  117
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E9%A9%AC%E8%BE%BE%E5%8A%A0%E6%96%AF%E5%8A%A0%E6%B0%91%E4%B8%BB%E5%85%B1%E5%92%8C%E5%9B%BD">
#                   马达加斯加民主共和国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇲🇬" title="表示“马达加斯加民主共和国”的Emoji表情符号：🇲🇬">
#                   🇲🇬
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  118
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E6%91%A9%E5%B0%94%E5%A4%9A%E7%93%A6%E5%85%B1%E5%92%8C%E5%9B%BD">
#                   摩尔多瓦共和国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇲🇩" title="表示“摩尔多瓦共和国”的Emoji表情符号：🇲🇩">
#                   🇲🇩
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  119
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E6%91%A9%E7%BA%B3%E5%93%A5%E4%BE%AF%E5%9B%BD">
#                   摩纳哥侯国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇲🇨" title="表示“摩纳哥侯国”的Emoji表情符号：🇲🇨">
#                   🇲🇨
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  120
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E6%91%A9%E7%BA%B3%E5%93%A5">
#                   摩纳哥
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇲🇨" title="表示“摩纳哥”的Emoji表情符号：🇲🇨">
#                   🇲🇨
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  121
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E6%91%A9%E6%B4%9B%E5%93%A5%E7%8E%8B%E5%9B%BD">
#                   摩洛哥王国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇲🇦" title="表示“摩洛哥王国”的Emoji表情符号：🇲🇦">
#                   🇲🇦
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  122
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E6%91%A9%E6%B4%9B%E5%93%A5">
#                   摩洛哥
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇲🇦" title="表示“摩洛哥”的Emoji表情符号：🇲🇦">
#                   🇲🇦
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  123
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E6%8B%89%E8%84%B1%E7%BB%B4%E4%BA%9A%E5%85%B1%E5%92%8C%E5%9B%BD">
#                   拉脱维亚共和国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇱🇻" title="表示“拉脱维亚共和国”的Emoji表情符号：🇱🇻">
#                   🇱🇻
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  124
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%88%A9%E6%AF%94%E4%BA%9A">
#                   利比亚
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇱🇾" title="表示“利比亚”的Emoji表情符号：🇱🇾">
#                   🇱🇾
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  125
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%8D%A2%E6%A3%AE%E5%A0%A1">
#                   卢森堡
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇱🇺" title="表示“卢森堡”的Emoji表情符号：🇱🇺">
#                   🇱🇺
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  126
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E7%AB%8B%E9%99%B6%E5%AE%9B">
#                   立陶宛
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇱🇹" title="表示“立陶宛”的Emoji表情符号：🇱🇹">
#                   🇱🇹
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  127
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E6%8B%89%E8%84%B1%E7%BB%B4%E4%BA%9A">
#                   拉脱维亚
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇱🇻" title="表示“拉脱维亚”的Emoji表情符号：🇱🇻">
#                   🇱🇻
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  128
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E6%96%AF%E9%87%8C%E5%85%B0%E5%8D%A1">
#                   斯里兰卡
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇱🇰" title="表示“斯里兰卡”的Emoji表情符号：🇱🇰">
#                   🇱🇰
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  129
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E6%96%AF%E9%87%8C%E5%85%B0%E5%8D%A1%E6%B0%91%E4%B8%BB%E7%A4%BE%E4%BC%9A%E4%B8%BB%E4%B9%89%E5%85%B1%E5%92%8C%E5%9B%BD">
#                   斯里兰卡民主社会主义共和国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇱🇰" title="表示“斯里兰卡民主社会主义共和国”的Emoji表情符号：🇱🇰">
#                   🇱🇰
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  130
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%88%97%E6%94%AF%E6%95%A6%E6%96%AF%E7%99%BB%E4%BE%AF%E5%9B%BD">
#                   列支敦斯登侯国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇱🇮" title="表示“列支敦斯登侯国”的Emoji表情符号：🇱🇮">
#                   🇱🇮
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  131
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%88%97%E6%94%AF%E6%95%A6%E6%96%AF%E7%99%BB">
#                   列支敦斯登
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇱🇮" title="表示“列支敦斯登”的Emoji表情符号：🇱🇮">
#                   🇱🇮
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  132
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E9%BB%8E%E5%B7%B4%E5%AB%A9">
#                   黎巴嫩
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇱🇧" title="表示“黎巴嫩”的Emoji表情符号：🇱🇧">
#                   🇱🇧
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  133
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E8%80%81%E6%8C%9D">
#                   老挝
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇱🇦" title="表示“老挝”的Emoji表情符号：🇱🇦">
#                   🇱🇦
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  134
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%93%88%E8%90%A8%E5%85%8B%E5%85%B1%E5%92%8C%E5%9B%BD">
#                   哈萨克共和国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇰🇿" title="表示“哈萨克共和国”的Emoji表情符号：🇰🇿">
#                   🇰🇿
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  135
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E7%A7%91%E5%A8%81%E7%89%B9">
#                   科威特
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇰🇼" title="表示“科威特”的Emoji表情符号：🇰🇼">
#                   🇰🇼
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  136
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E6%9C%9D%E9%B2%9C">
#                   朝鲜
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇰🇵" title="表示“朝鲜”的Emoji表情符号：🇰🇵">
#                   🇰🇵
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  137
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E9%9F%A9%E5%9B%BD">
#                   韩国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇰🇷" title="表示“韩国”的Emoji表情符号：🇰🇷">
#                   🇰🇷
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  138
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E6%9F%AC%E5%9F%94%E5%AF%A8">
#                   柬埔寨
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇰🇭" title="表示“柬埔寨”的Emoji表情符号：🇰🇭">
#                   🇰🇭
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  139
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E6%9F%AC%E5%9F%94%E5%AF%A8%E6%B0%91%E4%B8%BB%E5%9B%BD">
#                   柬埔寨民主国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇰🇭" title="表示“柬埔寨民主国”的Emoji表情符号：🇰🇭">
#                   🇰🇭
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  140
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E6%97%A5%E6%9C%AC">
#                   日本
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇯🇵" title="表示“日本”的Emoji表情符号：🇯🇵">
#                   🇯🇵
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  141
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E7%BA%A6%E6%97%A6">
#                   约旦
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇯🇴" title="表示“约旦”的Emoji表情符号：🇯🇴">
#                   🇯🇴
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  142
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E7%89%99%E4%B9%B0%E5%8A%A0">
#                   牙买加
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇯🇲" title="表示“牙买加”的Emoji表情符号：🇯🇲">
#                   🇯🇲
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  143
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E6%84%8F%E5%A4%A7%E5%88%A9">
#                   意大利
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇮🇹" title="表示“意大利”的Emoji表情符号：🇮🇹">
#                   🇮🇹
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  144
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E4%BC%8A%E6%8B%89%E5%85%8B">
#                   伊拉克
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇮🇶" title="表示“伊拉克”的Emoji表情符号：🇮🇶">
#                   🇮🇶
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  145
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E4%BC%8A%E6%9C%97">
#                   伊朗
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇮🇷" title="表示“伊朗”的Emoji表情符号：🇮🇷">
#                   🇮🇷
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  146
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%86%B0%E5%B2%9B">
#                   冰岛
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇮🇸" title="表示“冰岛”的Emoji表情符号：🇮🇸">
#                   🇮🇸
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  147
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%8D%B0%E5%BA%A6">
#                   印度
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇮🇳" title="表示“印度”的Emoji表情符号：🇮🇳">
#                   🇮🇳
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  148
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E4%BB%A5%E8%89%B2%E5%88%97">
#                   以色列
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇮🇱" title="表示“以色列”的Emoji表情符号：🇮🇱">
#                   🇮🇱
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  149
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E7%88%B1%E5%B0%94%E5%85%B0">
#                   爱尔兰
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇮🇪" title="表示“爱尔兰”的Emoji表情符号：🇮🇪">
#                   🇮🇪
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  150
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%8D%B0%E5%BA%A6%E5%B0%BC%E8%A5%BF%E4%BA%9A%E5%85%B1%E5%92%8C%E5%9B%BD">
#                   印度尼西亚共和国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇮🇩" title="表示“印度尼西亚共和国”的Emoji表情符号：🇮🇩">
#                   🇮🇩
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  151
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%8D%B0%E5%BA%A6%E5%B0%BC%E8%A5%BF%E4%BA%9A">
#                   印度尼西亚
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇮🇩" title="表示“印度尼西亚”的Emoji表情符号：🇮🇩">
#                   🇮🇩
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  152
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%8C%88%E7%89%99%E5%88%A9">
#                   匈牙利
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇭🇺" title="表示“匈牙利”的Emoji表情符号：🇭🇺">
#                   🇭🇺
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  153
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%8C%88%E7%89%99%E5%88%A9%E5%85%B1%E5%92%8C%E5%9B%BD">
#                   匈牙利共和国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇭🇺" title="表示“匈牙利共和国”的Emoji表情符号：🇭🇺">
#                   🇭🇺
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  154
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E6%B5%B7%E5%9C%B0">
#                   海地
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇭🇹" title="表示“海地”的Emoji表情符号：🇭🇹">
#                   🇭🇹
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  155
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E6%B5%B7%E5%9C%B0%E5%85%B1%E5%92%8C%E5%9B%BD">
#                   海地共和国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇭🇹" title="表示“海地共和国”的Emoji表情符号：🇭🇹">
#                   🇭🇹
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  156
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E9%A6%99%E6%B8%AF">
#                   香港
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇭🇰" title="表示“香港”的Emoji表情符号：🇭🇰">
#                   🇭🇰
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  157
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%9C%AD%E4%BA%9A%E9%82%A3">
#                   圭亚那
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇬🇾" title="表示“圭亚那”的Emoji表情符号：🇬🇾">
#                   🇬🇾
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  158
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%85%B3%E5%B2%9B">
#                   关岛
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇬🇺" title="表示“关岛”的Emoji表情符号：🇬🇺">
#                   🇬🇺
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  159
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%8D%B1%E5%9C%B0%E9%A9%AC%E6%8B%89">
#                   危地马拉
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇬🇹" title="表示“危地马拉”的Emoji表情符号：🇬🇹">
#                   🇬🇹
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  160
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%B8%8C%E8%85%8A">
#                   希腊
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇬🇷" title="表示“希腊”的Emoji表情符号：🇬🇷">
#                   🇬🇷
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  161
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E8%B5%A4%E9%81%93%E5%87%A0%E5%86%85%E4%BA%9A">
#                   赤道几内亚
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇬🇶" title="表示“赤道几内亚”的Emoji表情符号：🇬🇶">
#                   🇬🇶
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  162
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%87%A0%E5%86%85%E4%BA%9A">
#                   几内亚
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇬🇳" title="表示“几内亚”的Emoji表情符号：🇬🇳">
#                   🇬🇳
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  163
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E8%8B%B1%E5%9B%BD">
#                   英国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇬🇧" title="表示“英国”的Emoji表情符号：🇬🇧">
#                   🇬🇧
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
# ...
#                   🇨🇮
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  190
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E6%99%BA%E5%88%A9">
#                   智利
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇨🇱" title="表示“智利”的Emoji表情符号：🇨🇱">
#                   🇨🇱
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  191
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E7%91%9E%E5%A3%AB">
#                   瑞士
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇨🇭" title="表示“瑞士”的Emoji表情符号：🇨🇭">
#                   🇨🇭
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  192
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E7%91%9E%E5%A3%AB%E8%81%94%E9%82%A6">
#                   瑞士联邦
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇨🇭" title="表示“瑞士联邦”的Emoji表情符号：🇨🇭">
#                   🇨🇭
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  193
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E7%A7%91%E7%89%B9%E8%BF%AA%E7%93%A6%E5%85%B1%E5%92%8C%E5%9B%BD">
#                   科特迪瓦共和国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇨🇮" title="表示“科特迪瓦共和国”的Emoji表情符号：🇨🇮">
#                   🇨🇮
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  194
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%88%9A%E6%9E%9C">
#                   刚果
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇨🇬" title="表示“刚果”的Emoji表情符号：🇨🇬">
#                   🇨🇬
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  195
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E5%88%9A%E6%9E%9C%E4%BA%BA%E6%B0%91%E5%85%B1%E5%92%8C%E5%9B%BD">
#                   刚果人民共和国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇨🇬" title="表示“刚果人民共和国”的Emoji表情符号：🇨🇬">
#                   🇨🇬
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  196
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E4%B8%AD%E9%9D%9E%E5%85%B1%E5%92%8C%E5%9B%BD">
#                   中非共和国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇨🇫" title="表示“中非共和国”的Emoji表情符号：🇨🇫">
#                   🇨🇫
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  197
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E7%99%BD%E4%BF%84%E7%BD%97%E6%96%AF%E5%85%B1%E5%92%8C%E5%9B%BD">
#                   白俄罗斯共和国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇧🇾" title="表示“白俄罗斯共和国”的Emoji表情符号：🇧🇾">
#                   🇧🇾
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even">
#                 <td class="views-field views-field-counter">
#                  198
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E4%B8%8D%E4%B8%B9%E7%8E%8B%E5%9B%BD">
#                   不丹王国
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🇧🇹" title="表示“不丹王国”的Emoji表情符号：🇧🇹">
#                   🇧🇹
#                  </a>
#                 </td>
#                </tr>
#                <tr class="odd">
#                 <td class="views-field views-field-counter">
#                  199
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E4%B8%80%E4%B8%80%E2%97%8B">
#                   一一○
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🚓" title="表示“一一○”的Emoji表情符号：🚓">
#                   🚓
#                  </a>
#                  ,
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/👮" title="表示“一一○”的Emoji表情符号：👮">
#                   👮
#                  </a>
#                 </td>
#                </tr>
#                <tr class="even views-row-last">
#                 <td class="views-field views-field-counter">
#                  200
#                 </td>
#                 <td class="views-field views-field-title">
#                  <a href="/hanyu/%E4%B8%80%E4%B8%80%E2%97%8B">
#                   一一○
#                  </a>
#                 </td>
#                 <td class="views-field views-field-field-emoji">
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/🚓" title="表示“一一○”的Emoji表情符号：🚓">
#                   🚓
#                  </a>
#                  ,
#                  <a href="https://dict.emojiall.com/zh-hans/emoji/👮" title="表示“一一○”的Emoji表情符号：👮">
#                   👮
#                  </a>
#                 </td>
#                </tr>
#               </tbody>
#              </table>
#             </div>
#             <h2 class="element-invisible">
#              页面
#             </h2>
#             <div class="item-list">
#              <ul class="pager">
#               <li class="pager-first first">
#                <a href="/emoji" title="转到第一页">
#                 « 第一页
#                </a>
#               </li>
#               <li class="pager-previous">
#                <a href="/emoji" title="转到上一页">
#                 ‹ 前一页
#                </a>
#               </li>
#               <li class="pager-item">
#                <a href="/emoji" title="到第 1 页">
#                 1
#                </a>
#               </li>
#               <li class="pager-current">
#                2
#               </li>
#               <li class="pager-item">
#                <a href="/emoji?page=2" title="到第 3 页">
#                 3
#                </a>
#               </li>
#               <li class="pager-item">
#                <a href="/emoji?page=3" title="到第 4 页">
#                 4
#                </a>
#               </li>
#               <li class="pager-item">
#                <a href="/emoji?page=4" title="到第 5 页">
#                 5
#                </a>
#               </li>
#               <li class="pager-item">
#                <a href="/emoji?page=5" title="到第 6 页">
#                 6
#                </a>
#               </li>
#               <li class="pager-item">
#                <a href="/emoji?page=6" title="到第 7 页">
#                 7
#                </a>
#               </li>
#               <li class="pager-item">
#                <a href="/emoji?page=7" title="到第 8 页">
#                 8
#                </a>
#               </li>
#               <li class="pager-item">
#                <a href="/emoji?page=8" title="到第 9 页">
#                 9
#                </a>
#               </li>
#               <li class="pager-ellipsis">
#                …
#               </li>
#               <li class="pager-next">
#                <a href="/emoji?page=2" title="转到下一页">
#                 下一页 ›
#                </a>
#               </li>
#               <li class="pager-last last">
#                <a href="/emoji?page=10" title="转到最后一页">
#                 末页 »
#                </a>
#               </li>
#              </ul>
#             </div>
#             <div class="view-footer">
#              <ul>
#               <li>
#                <a href="https://chengyucidian.18dao.cn/emoji">
#                 部分成语人工翻译Emoji对照表
#                </a>
#               </li>
#               <li>
#                <a href="https://chengyucidian.18dao.cn/emoji1">
#                 所有成语自动翻译Emoji对照表
#                </a>
#               </li>
#               <li>
#                <a href="https://zhongwenzidian.18dao.cn/emoji">
#                 汉字Emoji对照表
#                </a>
#               </li>
#               <li>
#                <a href="https://zhongwenzidian.18dao.cn/to-emoji">
#                 汉字转对应Emoji
#                </a>
#               </li>
#              </ul>
#              <p>
#               请在以下输入框中输入需要查询对应Emoji的汉字：
#              </p>
#              <form action="/to-emoji" method="get" target="_top">
#               <input class="search_form" name="keyword" placeholder="成语/姓名/词语/句子..." size="32" type="text"/>
#               <input class="search_form" type="submit" value="查Emoji🔍"/>
#              </form>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <!-- /.section, /#content -->
#       <div class="column sidebar" id="sidebar-first">
#        <div class="section">
#         <div class="region region-sidebar-first">
#          <div class="block block-locale" id="block-locale-language">
#           <h2>
#            语言
#           </h2>
#           <div class="content">
#            <ul class="language-switcher-locale-url">
#             <li class="zh-hans first active">
#              <a class="language-link active" href="/emoji" xml:lang="zh-hans">
#               简体中文
#              </a>
#             </li>
#             <li class="zh-hant last">
#              <a class="language-link" href="/zh-hant/emoji" xml:lang="zh-hant">
#               繁體中文
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#         <!-- Baidu Union 18dao.cn Bottom PC 160x600 Jinjie 2018 -->
#         <div class="ad_yy_201901">
#          <script src="//d1.18dao.cn/source/cvibq.js?ni=afaekqa" type="text/javascript">
#          </script>
#         </div>
#        </div>
#       </div>
#       <!-- /.section, /#sidebar-first -->
#      </div>
#      <div style="width:100%; margin:0px auto; text-align:center;">
#       <a href="https://18dao.cn">
#        18dao.cn
#       </a>
#       <span>
#        2005-2019 v12.19 a-j-e-1   联系电话：027-65681210
#       </span>
#       <a href="/contact">
#        联络表
#       </a>
#       <p>
#        <a href="https://emojiall.com/zh-hans">
#         🙃Emoji中文网
#        </a>
#        :
#        <a href="https://copy.emojiall.com/zh-hans">
#         复制✂粘贴
#        </a>
#        、
#        <a href="https://emoji.18dao.net/zh-hans">
#         表情📝词典
#        </a>
#        、
#        <a href="https://zhongwenzidian.18dao.cn/to-emoji">
#         汉字转Emoji
#        </a>
#       </p>
#       <p>
#        <a href="https://hanyucidian.18dao.cn/emoji?page=1">
#         WEB
#        </a>
#        |
#        <a href="https://hanyucidian.18dao.cn/emoji?amp=&amp;page=1">
#         AMP
#        </a>
#        ⚡
#        <a href="https://hanyucidian.18dao.cn/emoji?mip=&amp;page=1">
#         MIP
#        </a>
#       </p>
#      </div>
#      <script type="text/javascript">
#       //封装nav_fixed
# 	function nav_fixed() {
# 		jQuery("#header").stickUp({});
# 	}
# 	//封装sidebar_fixed
# 	function sidebar_fixed() {
# 		jQuery(".region-sidebar-first + div[class^='ad']").stickUp({
# 			zIndex: 98,
# 			keepInWrapper: !0,
# 			topMargin: 100,
# 	        wrapperSelector: "#main-wrapper",
# 	    });
# 	}
# 	//sidebar默认收起点击展开
# //	$('#p-tb-label').click(function() {
# //	 $('#p-tb-label+.body').slideToggle("300")
# //	});
# 	//启动所有事件
# 	jQuery(document).ready(function() {
# 		nav_fixed();
# 		sidebar_fixed();
# 	});
#      </script>
#     </div>
#     <!-- /#main, /#main-wrapper -->
#     <div id="footer-wrapper">
#      <div class="section">
#       <!-----侯晓意修改-----!>
#
#
# 				<script type='text/javascript' language='javascript'>
# 		   (function($) {
# 				$(function() {
# 					var adss=location.href;
# 					console.log(adss);
# 					var shici='https://shicidaquan.18dao.cn/tangshi300';
# 					var chengyu='https://chengyucidian.18dao.cn/story-list';
# 					var isTrue=shici.indexOf(adss)&&chengyu.indexOf(adss);
# 					console.log(shici.indexOf(adss));
# 					console.log(chengyu.indexOf(adss));
#
# 					console.log(isTrue);
# 					if(isTrue=='0'){
#
# 						var btn1='<button  class="qwe" style="font-size:16px;margin-right:20px;">播放</button><input type="checkbox" name="selectAll" id="selectAll" >全选/全不选</input>';
#
# 						$('#page-title').after(btn1);
# 						$('#selectAll').click(function(){
# 							console.log(1);
# 							if ($("#selectAll").attr("checked")) {
# 							  $("input[name='selectbody']").attr("checked", true);
# 							} else {
# 							  $("input[name='selectbody']").attr("checked", false);
# 							}
# 						})
# 						window.onload=function(){
# 							function selectThis(obj) {
# 							var flag = false;
# 							if ($(obj).attr("checked") != "checked") {
# 							  flag = false;
# 							} else {
# 							  flag = true;
# 							  $("input[name='selectbody']").each(function() {
# 								if ($(this).attr("checked") != "checked") {
# 								  flag = false;
# 								}
# 							  })
# 							}
# 							if (flag) {
# 							  $("#selectAll").attr("checked", true);
# 							} else {
# 							  $("#selectAll").attr("checked", false);
# 							}
# 							}
# 						}
#
# 						$('.qwe').click(function(){
#                 var all=$("input[name='selectbody']");
# 				console.log(all);
# 				if($('.qwe').text()=="播放"){
#                     for(var i=0;i<all.length;i++){
#
#                     								if($(all[i]).attr("checked")){
# 														$('.qwe').text("暂停");
#                     								  var abc=$(all[i]).val();
# 													  console.log(abc);
# 													  console.log($("audio[src*="+abc+"]"))
# 													  $("audio[src*="+abc+"]")[0].play();
#
#                     								  $("audio[src*="+abc+"]")[0].addEventListener("ended", function(){
#                     									$("audio[src*="+$(all[i+1]).val()+"]")[0].play();
#                     								  });
#                     								  break;
#                     								}
#
#                     							}
#                 }else{
# 					$('.qwe').text("播放");
# 					for(var i=0;i<all.length;i++){
# 						if($(all[i]).attr("checked")){
# 														var abc=$(all[i]).val();
#                     								  $("audio[src*="+abc+"]")[0].pause();
#
#                     								}
# 					}
#
#
#                 }
#
#
#             })
# 				}
# 				});
# 			})(jQuery);
# 		</script>
#
#
#   </div></div> <!-- /.section, /#footer-wrapper -->
#      </div>
#     </div>
#     <!-- /#page, /#page-wrapper -->
#     <script type="text/javascript">
#      <!--//--><![CDATA[//><!--
# SyntaxHighlighter.all();
# //--><!]]>
#     </script>
#    </div>
#   </div>
#  </body>
# </html>

# %%
<td class="views-field views-field-title">
            <a href="/hanyu/%E6%8C%AA%E5%A8%81">挪威</a>          </td>

# %%
tree=etree.HTML(html)

# %%
chinese=tree.xpath('//td[2][@class]/a[@href]/text()')
emoji=tree.xpath('//td[3][@class]/a[1][@href]/text()')

# %%
emoji=tree.xpath('//td[3][@class]/a[1][@href]/text()')

# %%
a
# Out:
# {1}

# %%
a.add(1)

# %%
emoji_dict=dict()

# %%
for i in range(0,len(emoji)):
    try:
        if emoji[i] not in emoji_dict:
            emoji_dict[emoji[i]]=set()
            emoji_dict[emoji[i]].add(chinese[i])
        else:
            emoji_dict[emoji[i]].add(chinese[i])
    except Exception as e:
        print(i)
        print(e)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b40fcaf99bdf> in <module>
# ----> 1 for i in range(0,len(emoji)):
#       2     try:
#       3         if emoji[i] not in emoji_dict:
#       4             emoji_dict[emoji[i]]=set()
#       5             emoji_dict[emoji[i]].add(chinese[i])
#
# NameError: name 'emoji' is not defined

# %%
emoji_dict
# Out:
# {'🇳🇴': {'挪威'},
#  '🇳🇵': {'尼泊尔', '尼泊尔王国'},
#  '🇳🇱': {'荷兰'},
#  '🇳🇮': {'尼加拉瓜'},
#  '🇳🇦': {'纳米比亚共和国'},
#  '🇲🇾': {'马来西亚'},
#  '🇲🇿': {'莫桑比克'},
#  '🇲🇽': {'墨西哥'},
#  '🇲🇹': {'马耳他'},
#  '🇲🇴': {'澳门'},
#  '🇲🇳': {'外蒙古'},
#  '🇲🇲': {'缅甸'},
#  '🇲🇱': {'马利共和国'},
#  '🇲🇬': {'马达加斯加', '马达加斯加民主共和国'},
#  '🇲🇰': {'马其顿王国'},
#  '🇲🇩': {'摩尔多瓦共和国'},
#  '🇲🇨': {'摩纳哥', '摩纳哥侯国'},
#  '🇲🇦': {'摩洛哥', '摩洛哥王国'},
#  '🇱🇻': {'拉脱维亚', '拉脱维亚共和国'},
#  '🇱🇾': {'利比亚'},
#  '🇱🇺': {'卢森堡'},
#  '🇱🇹': {'立陶宛'},
#  '🇱🇰': {'斯里兰卡', '斯里兰卡民主社会主义共和国'},
#  '🇱🇮': {'列支敦斯登', '列支敦斯登侯国'},
#  '🇱🇧': {'黎巴嫩'},
#  '🇱🇦': {'老挝'},
#  '🇰🇿': {'哈萨克共和国'},
#  '🇰🇼': {'科威特'},
#  '🇰🇵': {'朝鲜'},
#  '🇰🇷': {'韩国'},
#  '🇰🇭': {'柬埔寨', '柬埔寨民主国'},
#  '🇯🇵': {'日本'},
#  '🇯🇴': {'约旦'},
#  '🇯🇲': {'牙买加'},
#  '🇮🇹': {'意大利'},
#  '🇮🇶': {'伊拉克'},
#  '🇮🇷': {'伊朗'},
#  '🇮🇸': {'冰岛'},
#  '🇮🇳': {'印度'},
#  '🇮🇱': {'以色列'},
#  '🇮🇪': {'爱尔兰'},
#  '🇮🇩': {'印度尼西亚', '印度尼西亚共和国'},
#  '🇭🇺': {'匈牙利', '匈牙利共和国'},
#  '🇭🇹': {'海地', '海地共和国'},
#  '🇭🇰': {'香港'},
#  '🇬🇾': {'圭亚那'},
#  '🇬🇺': {'关岛'},
#  '🇬🇹': {'危地马拉'},
#  '🇬🇷': {'希腊'},
#  '🇬🇶': {'赤道几内亚'},
#  '🇬🇳': {'几内亚'},
#  '🇬🇧': {'英国'},
#  '🇫🇷': {'法国'},
#  '🇫🇲': {'密克罗尼西亚'},
#  '🇫🇯': {'斐济'},
#  '🇫🇮': {'芬兰'},
#  '🇪🇸': {'西班牙', '西班牙王国'},
#  '🇪🇬': {'埃及'},
#  '🇪🇪': {'爱沙尼亚'},
#  '🇩🇲': {'多米尼加'},
#  '🇩🇴': {'多米尼加共和国'},
#  '🇩🇰': {'丹麦'},
#  '🇩🇿': {'阿尔及利亚'},
#  '🇩🇯': {'吉布提'},
#  '🇩🇪': {'德国', '德意志联邦共和国'},
#  '🇨🇾': {'塞浦路斯', '塞浦路斯共和国'},
#  '🇨🇺': {'古巴', '古巴共和国'},
#  '🇨🇷': {'哥斯达黎加', '哥斯达黎加共和国'},
#  '🇨🇴': {'哥伦比亚', '哥伦比亚共和国'},
#  '🇨🇲': {'喀麦隆', '喀麦隆共和国'},
#  '🇨🇮': {'科特迪瓦', '科特迪瓦共和国'},
#  '🇨🇱': {'智利'},
#  '🇨🇭': {'瑞士', '瑞士联邦'},
#  '🇨🇬': {'刚果', '刚果人民共和国'},
#  '🇨🇫': {'中非共和国'},
#  '🇧🇾': {'白俄罗斯共和国'},
#  '🇧🇹': {'不丹王国'},
#  '🚓': {'一一○'}}

# %%
def get_emoji_dict():
    """
        return: eomji_dict emoji字典
    """
    emoji_dict=dict()
    for offset in range(0, 11):
        url = 'https://hanyucidian.18dao.cn/emoji?page=0'+str(offset)
        tree=emoji_spider(url)
        chinese, emoji=html_parser(tree)
        for i in range(0,len(emoji)):
            try:
                if emoji[i] not in emoji_dict:
                    emoji_dict[emoji[i]]=set()
                    emoji_dict[emoji[i]].add(chinese[i])
                else:
                    emoji_dict[emoji[i]].add(chinese[i])
            except Exception as e:
                print(e)
        print('page '+str(offset) +' get emoji over!' )
        time.sleep(2)
    return emoji_dict

# %%
def emoji_spider(url):
    """
        爬取emoji页面
        url: emoji页面的url
        return: tree lxml.etree._Element类型对象
    """
    headers={'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36'}
    try:
        r=requests.get(url,headers=headers)
        r.raise_for_status()
        html=r.text
        tree=etree.HTML(html)
        return tree
    except Exception as e:
        print("spider failed")
        print(e)

# %%
def html_parser(tree):
    """
        解析抓取的html页面
        tree: lxml.etree._Element类型对象
        return: chinese, dict type: list
    """
    chinese=tree.xpath('//td[2][@class]/a[@href]/text()')
    emoji=tree.xpath('//td[3][@class]/a[1][@href]/text()')
    return chinese, emoji

# %%
emoji_list=get_emoji_dict()
# Out:
# page 0get emoji over!
# page 1get emoji over!
# page 2get emoji over!
# page 3get emoji over!
# page 4get emoji over!
# page 5get emoji over!
# page 6get emoji over!
# page 7get emoji over!
# page 8get emoji over!
# page 9get emoji over!
# page 10get emoji over!

# %%
emoji_list
# Out:
# {'⚽': {'足球'},
#  '🎆': {'焰火'},
#  '🎇': {'烟花'},
#  '🎁': {'礼物'},
#  '🎖': {'勋章'},
#  '🇨🇳': {'中国'},
#  '🏁': {'终点'},
#  '🇵🇾': {'巴拉圭', '巴拉圭共和国'},
#  '🇦🇩': {'安道尔'},
#  '🇦🇪': {'阿拉伯联合大公国'},
#  '🇦🇫': {'阿富汗'},
#  '🇦🇱': {'阿尔巴尼亚'},
#  '🇦🇲': {'亚美尼亚'},
#  '🇦🇷': {'阿根廷共和国'},
#  '🇦🇶': {'南极洲'},
#  '🇦🇴': {'安哥拉'},
#  '🇦🇹': {'奥地利'},
#  '🇦🇺': {'澳大利亚'},
#  '🇧🇪': {'比利时'},
#  '🇧🇩': {'孟加拉国'},
#  '🇧🇭': {'巴林'},
#  '🇧🇬': {'保加利亚'},
#  '🇧🇳': {'文莱'},
#  '🇧🇷': {'巴西'},
#  '🇧🇹': {'不丹', '不丹王国'},
#  '🇧🇴': {'玻利维亚'},
#  '🇧🇾': {'白俄罗斯', '白俄罗斯共和国'},
#  '🇨🇦': {'加拿大'},
#  '🥪': {'三明治'},
#  '☢': {'辐射'},
#  '♈': {'白羊座'},
#  '♌': {'狮子座'},
#  '♉': {'金牛座'},
#  '♊': {'双子座'},
#  '♑': {'摩羯座'},
#  '♋': {'巨蟹座'},
#  '♎': {'天秤座'},
#  '♍': {'处女座'},
#  '♏': {'天蝎座'},
#  '♓': {'双鱼座'},
#  '❓': {'疑问号', '问号'},
#  '✝': {'十字架', '基督教'},
#  '™': {'商标', '注册商标'},
#  '🚾': {'厕所'},
#  '♿': {'轮椅'},
#  'ℹ': {'信息', '咨询'},
#  '🛂': {'护照'},
#  '🛃': {'海关'},
#  '🛄': {'提取', '行李'},
#  '🛅': {'寄存'},
#  '㊗': {'祝贺'},
#  '㊙': {'秘密'},
#  '🅿': {'停车', '停车位', '停车场'},
#  '🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f': {'英格兰'},
#  '🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f': {'苏格兰'},
#  '🇿🇲': {'赞比亚'},
#  '🇿🇼': {'津巴布韦'},
#  '🇿🇦': {'南非'},
#  '🇾🇪': {'也门'},
#  '🇻🇳': {'越南'},
#  '🇻🇪': {'委内瑞拉'},
#  '🇺🇾': {'乌拉圭'},
#  '🇻🇦': {'梵蒂冈'},
#  '🇺🇸': {'美国'},
#  '🇺🇳': {'联合国'},
#  '🇺🇦': {'乌克兰'},
#  '🇺🇬': {'乌干达'},
#  '🇹🇼': {'台湾'},
#  '🇹🇷': {'土耳其'},
#  '🇹🇳': {'突尼斯'},
#  '🇹🇭': {'泰国'},
#  '🇸🇲': {'圣马力诺'},
#  '🇸🇳': {'塞内加尔'},
#  '🇸🇰': {'斯洛伐克共和国'},
#  '🇨🇿': {'捷克共和国'},
#  '🇸🇬': {'新加坡', '新加坡共和国'},
#  '🇸🇪': {'瑞典'},
#  '🇸🇩': {'苏丹'},
#  '🇷🇼': {'卢旺达共和国'},
#  '🇸🇦': {'沙特阿拉伯', '沙特阿拉伯王国'},
#  '🇷🇺': {'俄罗斯'},
#  '🇷🇸': {'塞尔维亚'},
#  '🇷🇴': {'罗马尼亚'},
#  '🇵🇹': {'葡萄牙'},
#  '🇵🇸': {'巴勒斯坦'},
#  '🇵🇷': {'波多黎各'},
#  '🇵🇱': {'波兰'},
#  '🇵🇰': {'巴基斯坦'},
#  '🇵🇬': {'新几内亚岛'},
#  '🇵🇭': {'菲律宾'},
#  '🇵🇪': {'秘鲁'},
#  '🇵🇦': {'巴拿马'},
#  '🇴🇲': {'阿曼'},
#  '🇳🇿': {'纽西兰'},
#  '🇳🇴': {'挪威'},
#  '🇳🇵': {'尼泊尔', '尼泊尔王国'},
#  '🇳🇱': {'荷兰'},
#  '🇳🇮': {'尼加拉瓜'},
#  '🇳🇦': {'纳米比亚共和国'},
#  '🇲🇾': {'马来西亚'},
#  '🇲🇿': {'莫桑比克'},
#  '🇲🇽': {'墨西哥'},
#  '🇲🇹': {'马耳他'},
#  '🇲🇴': {'澳门'},
#  '🇲🇳': {'外蒙古'},
#  '🇲🇲': {'缅甸'},
#  '🇲🇱': {'马利共和国'},
#  '🇲🇬': {'马达加斯加', '马达加斯加民主共和国'},
#  '🇲🇰': {'马其顿王国'},
#  '🇲🇩': {'摩尔多瓦共和国'},
#  '🇲🇨': {'摩纳哥', '摩纳哥侯国'},
#  '🇲🇦': {'摩洛哥', '摩洛哥王国'},
#  '🇱🇻': {'拉脱维亚', '拉脱维亚共和国'},
#  '🇱🇾': {'利比亚'},
#  '🇱🇺': {'卢森堡'},
#  '🇱🇹': {'立陶宛'},
#  '🇱🇰': {'斯里兰卡', '斯里兰卡民主社会主义共和国'},
#  '🇱🇮': {'列支敦斯登', '列支敦斯登侯国'},
#  '🇱🇧': {'黎巴嫩'},
#  '🇱🇦': {'老挝'},
#  '🇰🇿': {'哈萨克共和国'},
#  '🇰🇼': {'科威特'},
#  '🇰🇵': {'朝鲜'},
#  '🇰🇷': {'韩国'},
#  '🇰🇭': {'柬埔寨', '柬埔寨民主国'},
#  '🇯🇵': {'日本'},
#  '🇯🇴': {'约旦'},
#  '🇯🇲': {'牙买加'},
#  '🇮🇹': {'意大利'},
#  '🇮🇶': {'伊拉克'},
#  '🇮🇷': {'伊朗'},
#  '🇮🇸': {'冰岛'},
#  '🇮🇳': {'印度'},
#  '🇮🇱': {'以色列'},
#  '🇮🇪': {'爱尔兰'},
#  '🇮🇩': {'印度尼西亚', '印度尼西亚共和国'},
#  '🇭🇺': {'匈牙利', '匈牙利共和国'},
#  '🇭🇹': {'海地', '海地共和国'},
#  '🇭🇰': {'香港'},
#  '🇬🇾': {'圭亚那'},
#  '🇬🇺': {'关岛'},
#  '🇬🇹': {'危地马拉'},
#  '🇬🇷': {'希腊'},
#  '🇬🇶': {'赤道几内亚'},
#  '🇬🇳': {'几内亚'},
#  '🇬🇧': {'大不列颠', '英国'},
#  '🇫🇷': {'法国'},
#  '🇫🇯': {'斐济'},
#  '🇫🇲': {'密克罗尼西亚'},
#  '🇫🇮': {'芬兰'},
#  '🇪🇸': {'西班牙', '西班牙王国'},
#  '🇪🇬': {'埃及'},
#  '🇪🇪': {'爱沙尼亚'},
#  '🇩🇲': {'多米尼加'},
#  '🇩🇴': {'多米尼加共和国'},
#  '🇩🇰': {'丹麦'},
#  '🇩🇿': {'阿尔及利亚'},
#  '🇩🇯': {'吉布提'},
#  '🇩🇪': {'德国', '德意志联邦共和国'},
#  '🇨🇾': {'塞浦路斯', '塞浦路斯共和国'},
#  '🇨🇺': {'古巴', '古巴共和国'},
#  '🇨🇷': {'哥斯达黎加', '哥斯达黎加共和国'},
#  '🇨🇴': {'哥伦比亚', '哥伦比亚共和国'},
#  '🇨🇲': {'喀麦隆', '喀麦隆共和国'},
#  '🇨🇮': {'科特迪瓦', '科特迪瓦共和国'},
#  '🇨🇱': {'智利'},
#  '🇨🇭': {'瑞士', '瑞士联邦'},
#  '🇨🇬': {'刚果', '刚果人民共和国'},
#  '🇨🇫': {'中非共和国'},
#  '🚓': {'一一○'},
#  '🚒': {'一一九', '消防车'},
#  '👨': {'一丁', '男人'},
#  '↑': {'一上'},
#  '↓': {'一下'},
#  '⏳': {'一下子'},
#  '🧑': {'一人', '成人'},
#  '1️⃣': {'一个'},
#  '🏳️': {'举白旗', '白旗'},
#  '📐': {'三角', '三角尺'},
#  '🎌': {'交叉'},
#  '⬜': {'方块', '方形', '方框', '白色'},
#  '⬛': {'黑色'},
#  '\U0001f7e5': {'红色'},
#  '\U0001f7e6': {'蓝色'},
#  '\U0001f7e8': {'黄色'},
#  '\U0001f7e9': {'绿色'},
#  '\U0001f7ea': {'紫色'},
#  '\U0001f7eb': {'棕色'},
#  '⚪': {'圆形'},
#  '🔷': {'菱形'},
#  '🌜': {'月色'},
#  '🔺': {'三角形'},
#  '🌱': {'幼苗', '春色'},
#  '🌈': {'彩色', '彩虹'},
#  '🌃': {'夜晚', '夜色'},
#  '🥵': {'酷热'},
#  '🆘': {'抢救', '援救', '救命', '救援'},
#  '🈁': {'这里'},
#  '🆚': {'对抗', '比赛'},
#  '🏎': {'赛车'},
#  '🈂': {'小费'},
#  '🈚': {'免费'},
#  '🈯': {'保留'},
#  '🚫': {'禁止'},
#  '🈳': {'空位'},
#  '💺': {'坐位'},
#  '🈴': {'合格'},
#  '🈵': {'客满'},
#  '🈶': {'付费'},
#  '🈸': {'申请'},
#  '🈹': {'打折', '折扣'},
#  '🈺': {'营业'},
#  '🉐': {'讨价还价', '议价', '还价'},
#  '🉑': {'可行'},
#  '🔡': {'小写'},
#  '🔠': {'大写', '字母'},
#  '🔢': {'数字'},
#  '🔣': {'标点', '符号'},
#  '🔤': {'拉丁字母'},
#  '🆖': {'不好'},
#  '🆑': {'清除'},
#  '©': {'版权', '版权所有'},
#  '®': {'注册'},
#  '❗': {'感叹'},
#  '♻': {'回收'},
#  '♾': {'无限'},
#  '⚕': {'医疗'},
#  '⚜': {'百合花'},
#  '✔': {'打勾'},
#  '✖': {'乘号'},
#  '❇': {'火花'},
#  '❌': {'打叉'},
#  '➕': {'加号'},
#  '➖': {'减号'},
#  '➰': {'卷曲'},
#  '➗': {'除号'},
#  '⭕': {'圆圈'},
#  '🌊': {'波浪', '浪花'},
#  '〰': {'破折号'},
#  '📛': {'姓名'},
#  '🔱': {'画戟'},
#  '🔰': {'新手'},
#  '🎨': {'画板'},
#  '♂': {'男性', '雄性'},
#  '♀': {'女性', '雌性'},
#  '⏏': {'推出', '退出'},
#  '⏩': {'前进'},
#  '⏪': {'倒退', '后退'},
#  '↗': {'上升'},
#  '⏸': {'暂停'},
#  '⏹': {'停止'},
#  '⏺': {'录制'},
#  '🎛': {'控制'},
#  '▶': {'播放'},
#  '🎦': {'电影', '电影院'},
#  '📳': {'振动', '震动'},
#  '📴': {'关机'},
#  '📶': {'信号', '强度'},
#  '🔀': {'随机变数'},
#  '🔁': {'循环', '重复'},
#  '🔆': {'亮度'},
#  '🔼': {'向上'},
#  '♒': {'宝瓶座'},
#  '🌠': {'流星', '流星雨'},
#  '🌌': {'人马座', '银河', '银河系'},
#  '☄': {'彗尾', '彗星'},
#  '☦': {'正教'},
#  '☪': {'伊斯兰教'},
#  '☮': {'和平'},
#  '☯': {'道教', '阴阳'},
#  '⚛': {'原子', '原子符号'},
#  '☸': {'法轮'},
#  '✡': {'犹太教'},
#  '🕉️': {'佛教', '印度教', '锡克教'},
#  '🕎': {'烛台'},
#  '🛐': {'宗教', '忏悔', '祈祷'},
#  '↔': {'箭头'},
#  '⚠': {'警告'},
#  '🚭': {'禁烟'},
#  '🏧': {'提款'},
#  '🚰': {'净水', '饮水'},
#  '🚱': {'原水', '污水', '浑水'},
#  '🚼': {'宝宝'},
#  '⚰': {'棺材'},
#  '⚱': {'骨灰', '骨灰坛'},
#  '🚬': {'香烟'},
#  '🗿': {'石像'},
#  '\U0001fa91': {'椅子'},
#  '🧽': {'海绵'},
#  '\U0001fa92': {'刮脸', '剃刀'},
#  '🧻': {'卫生纸', '卷纸'},
#  '🧼': {'皂', '肥皂'},
#  '🧺': {'筐', '篓筐'},
#  '🧹': {'扫帚'},
#  '🧷': {'别针'},
#  '🧴': {'化妆品'},
#  '🧯': {'灭火器'},
#  '🛋': {'沙发'},
#  '🚿': {'淋浴'},
#  '🛁': {'浴缸'},
#  '🚽': {'马桶'},
#  '\U0001fa7a': {'听筒', '听诊器'},
#  '\U0001fa78': {'滴血'},
#  '💊': {'胶囊', '药丸'},
#  '🎞': {'胶片'},
#  '💉': {'打针', '注射', '注射器'},
#  '⚗': {'蒸馏', '蒸馏器'},
#  '📡': {'天线'},
#  '🛰': {'卫星'},
#  '🔬': {'显微镜'},
#  '🔭': {'望远镜'},
#  '🧪': {'试管'},
#  '🧫': {'培养皿'},
#  '🤱': {'养育', '喂养'},
#  '🧬': {'基因', '核糖核酸'},
#  '🔨': {'锤子'},
#  '⚔': {'交战'},
#  '⚙': {'齿轮'},
#  '⚖': {'天平'},
#  '⛏': {'十字镐'},
#  '⛓': {'链子', '链条'},
#  '🏹': {'弓箭'},
#  '🔗': {'连接'},
#  '🔧': {'扳子', '扳手', '搬子'},
#  '🔩': {'螺栓', '螺母'},
#  '🔫': {'手枪'},
#  '🗜': {'卡钳', '虎钳', '钳子'},
#  '👨\u200d🔧': {'钳工'},
#  '👨\u200d🏭': {'铆接'},
#  '🗡': {'匕首'},
#  '🛡': {'盾牌'},
#  '\U0001f9af': {'手杖', '拐杖', '马杆'},
#  '👨\u200d\U0001f9af': {'拄杖'},
#  '🧰': {'工具'},
#  '🧲': {'磁铁'},
#  '\U0001fa93': {'斧头', '斧子'},
#  '🔑': {'钥匙'},
#  '🔒': {'闭锁'},
#  '✂': {'剪刀'},
#  '📜': {'卷宗', '卷轴'},
#  '📁': {'资料文件'},
#  '📄': {'文件'},
#  '📅': {'日历'},
#  '🍹': {'饮料'},
#  '📆': {'日历年度'},
#  '📇': {'卡片'},
#  '📉': {'下挫', '下降', '失败'},
#  '📈': {'上涨', '成功'},
#  '📊': {'条形图'},
#  '📋': {'剪贴', '剪贴簿'},
#  '📌': {'图钉'},
#  '📍': {'大头针'},
#  '📎': {'回形针'},
#  '📏': {'直尺'},
#  '🗃': {'卡片目录'},
#  '🗂': {'索引'},
#  '🗄': {'柜子'},
#  '🗑': {'垃圾桶'},
#  '🗒': {'活页夹', '活页装订'},
#  '👥': {'双簧'},
#  '*': {'星号'},
#  'test': {'测试'},
#  '☁': {'云'},
#  '☇': {'闪电'},
#  '⏱': {'秒表'},
#  '⏰': {'闹钟'},
#  '⌨': {'键盘'},
#  '☀': {'太阳'},
#  '⌚': {'手表'},
#  '☈': {'雷雨'},
#  '☂': {'伞'},
#  '⌛': {'沙漏'},
#  '🍋': {'柠檬'},
#  '\U0001f9c4': {'蒜'},
#  '🍜': {'面条'},
#  '🍶': {'清酒'},
#  '🦉': {'猫头鹰'},
#  '🌽': {'玉米'},
#  '🤷': {'耸肩'},
#  '🍙': {'饭团'},
#  '🐃': {'水牛'},
#  '🕷': {'蜘蛛'},
#  '🍕': {'披萨'},
#  '🌕': {'满月'},
#  '😑': {'无语'},
#  '🚝': {'单轨'},
#  '🦠': {'细菌'},
#  '🤤': {'流口水'},
#  '🚲': {'自行车'},
#  '🚶': {'行人'},
#  '\U0001fa73': {'短裤'},
#  '📧': {'电子邮件'},
#  '💌': {'情书'},
#  '👻': {'鬼'},
#  '🥓': {'培根'},
#  '☿': {'水星'},
#  '🥈': {'银牌'},
#  '📝': {'备忘录'},
#  '🎺': {'小号'},
#  '🎿': {'滑雪'},
#  '🍇': {'葡萄'},
#  '🖐': {'手掌'},
#  '😠': {'生气'},
#  '👘': {'和服'},
#  '🦌': {'鹿'},
#  '🐖': {'猪'},
#  '⛪': {'教堂'},
#  '🥢': {'筷子'},
#  '🦒': {'长颈鹿'},
#  '\U0001f9ca': {'冰块'},
#  '🎅': {'圣诞老人'},
#  '\U0001fa72': {'三角裤'},
#  '🥏': {'飞盘'},
#  '🐍': {'蛇'},
#  '📢': {'喇叭'},
#  '🌪': {'龙卷风'},
#  '🚉': {'车站'},
#  '🚡': {'索道'},
#  '😋': {'好吃'},
#  '⛅': {'阴'},
#  '🦔': {'刺猬'},
#  '🐾': {'爪印'},
#  '🏓': {'乒乓球'},
#  '🦂': {'蝎子'},
#  '👁': {'眼睛'},
#  '🧣': {'围巾'},
#  '🏨': {'酒店'},
#  '🥮': {'月饼'},
#  '😨': {'害怕'},
#  '❄': {'雪花'},
#  '🥜': {'花生'},
#  '💢': {'怒'},
#  '🛶': {'独木舟'},
#  '🛣': {'高速公路'},
#  '💏': {'亲吻'},
#  '🤸': {'侧手翻'},
#  '♣': {'梅花'},
#  '⛸': {'滑冰'},
#  '🍂': {'落叶'},
#  '🐞': {'瓢虫'},
#  '🧛': {'吸血鬼'},
#  '🦅': {'鹰'},
#  '🏜': {'沙漠'},
#  '🚌': {'公交车'},
#  '👂': {'耳朵'},
#  '💣': {'炸弹'},
#  '🎐': {'风铃'},
#  '🌩': {'打雷'},
#  '🍺': {'啤酒'},
#  '🕌': {'清真寺'},
#  '🍧': {'刨冰'},
#  '👣': {'脚印'},
#  '💥': {'爆炸'},
#  '🐎': {'马'},
#  '😖': {'困惑'},
#  '🎒': {'书包'},
#  '🐚': {'海螺'},
#  '⛄': {'雪人'},
#  '🌺': {'芙蓉'},
#  '💓': {'心跳'},
#  '🌵': {'仙人掌'},
#  '🏟': {'体育馆'},
#  '🎡': {'摩天轮'},
#  '🎫': {'票'},
#  '🐛': {'毛毛虫'},
#  '✏': {'铅笔'},
#  '🌡': {'温度计'},
#  '😲': {'震惊'},
#  '🔪': {'菜刀'},
#  '😛': {'吐舌'},
#  '🍍': {'菠萝'},
#  '📻': {'收音机'},
#  '🖊': {'笔'},
#  '🍣': {'寿司'},
#  '😔': {'沉思'},
#  '🏄': {'冲浪'},
#  '🤑': {'发财'},
#  '♪': {'八分音符'},
#  '🍊': {'橘子'},
#  '💀': {'头骨'},
#  '🧧': {'红包'},
#  '🕐': {'一点'},
#  '🥁': {'鼓'},
#  '🤧': {'打喷嚏'},
#  '💡': {'灯泡'},
#  '😦': {'啊'},
#  '😞': {'失望'},
#  '🍤': {'天妇罗'},
#  '🐅': {'老虎'},
#  '🧩': {'拼图'},
#  '🐵': {'猴头'},
#  '⛲': {'喷泉'},
#  '🏫': {'学校'},
#  '💄': {'唇膏'},
#  '🦴': {'骨头'},
#  '🐌': {'蜗牛'},
#  '🤘': {'摇滚'},
#  '🏏': {'板球'},
#  '🐋': {'鲸鱼'},
#  '😷': {'感冒'},
#  '🌋': {'火山'},
#  '📣': {'扩音器'},
#  '🥇': {'金牌'},
#  '🐇': {'兔子'},
#  '🏷': {'标签'},
#  '👔': {'领带'},
#  '🍡': {'团子'},
#  '🖵': {'屏幕'},
#  '🔋': {'电池'},
#  '🍓': {'草莓'},
#  '😢': {'哭'},
#  '🤥': {'说谎'},
#  '🧱': {'砖'},
#  '🦢': {'天鹅'},
#  '🐘': {'大象'},
#  '👛': {'钱包'},
#  '🍴': {'刀叉'},
#  '👵': {'老奶奶'},
#  '🍪': {'饼干'},
#  '🧵': {'线'},
#  '📒': {'账本'},
#  '🦏': {'犀牛'},
#  '😁': {'嘻嘻'},
#  '🛍': {'购物袋'},
#  '🥂': {'碰杯'},
#  '🤰': {'孕妇'},
#  '🕉': {'奥姆'},
#  '🐪': {'骆驼'},
#  '😏': {'得意'},
#  '🦐': {'虾'},
#  '🤝': {'握手'},
#  '🥅': {'球门'},
#  '🥔': {'土豆'},
#  '🗻': {'富士山'},
#  '\U0001f9a6': {'水獭'},
#  '\U0001f9a8': {'臭鼬'},
#  '🐟': {'鱼'},
#  '🤔': {'想一想'},
#  '🍔': {'汉堡'},
#  '📨': {'来信'},
#  '🍅': {'西红柿'},
#  '📰': {'报纸'},
#  '🏥': {'医院'},
#  '🙇': {'鞠躬'},
#  '🏀': {'篮球'},
#  '\U0001f9c8': {'黄油'},
#  '🤾': {'手球'},
#  '🚎': {'无轨电车'},
#  '🦓': {'斑马'},
#  '👑': {'皇冠'},
#  '📼': {'录像带'},
#  '🏒': {'冰球'},
#  '🦷': {'牙齿'},
#  '🤮': {'呕吐'},
#  '🚚': {'货车'},
#  '🧤': {'手套'},
#  '🐝': {'蜜蜂'},
#  '🤴': {'王子'},
#  '💳': {'信用卡'},
#  '♃': {'木星'},
#  '🥄': {'匙'},
#  '😳': {'脸红'},
#  '😡': {'怒火中烧'},
#  '🏂': {'滑雪板'},
#  '🕯': {'蜡烛'},
#  '😤': {'傲慢'},
#  '⚾': {'棒球'},
#  '🏗': {'施工'},
#  '💮': {'白花'},
#  '🛸': {'飞碟'},
#  '🧞': {'妖怪'},
#  '🥚': {'蛋'},
#  '🦞': {'龙虾'},
#  '💾': {'软盘'},
#  '🏐': {'排球'},
#  '🌑': {'朔月'},
#  '👓': {'眼镜'},
#  '👪': {'家庭'},
#  '😃': {'哈哈'},
#  '🥌': {'冰壶'},
#  '🥝': {'猕猴桃'},
#  '⛈': {'雷阵雨'},
#  '🎩': {'礼帽'},
#  '😍': {'花痴'},
#  '🔮': {'水晶球'},
#  '🕫': {'喇叭筒'},
#  '🚕': {'出租车'},
#  '👜': {'手提包'},
#  '🏦': {'银行'},
#  '🧮': {'算盘'},
#  '🎤': {'麦克风'},
#  '🛤': {'铁轨'},
#  '🦳': {'白发'},
#  '🎧': {'耳机'},
#  '😘': {'飞吻'},
#  '👚': {'女装'},
#  '😬': {'龇牙咧嘴'},
#  '\U0001f9c5': {'洋葱'},
#  '🕵': {'侦探'},
#  '🧨': {'爆竹'},
#  '\U0001fa82': {'降落伞'},
#  '🔖': {'书签'},
#  '📷': {'相机'},
#  '🦵': {'腿'},
#  '🙂': {'呵呵'},
#  '🦗': {'蟋蟀'},
#  '🚤': {'快艇'},
#  '🐬': {'海豚'},
#  '♟︎': {'兵'},
#  '🏤': {'邮局'},
#  '🏍': {'摩托车'},
#  '🏆': {'奖杯'},
#  '🏔': {'雪山'},
#  '⚡': {'高压'},
#  '🎻': {'小提琴'},
#  '🧶': {'毛线'},
#  '💍': {'戒指'},
#  '🛹': {'滑板'},
#  '\U0001f9ba': {'救生衣'},
#  '🍈': {'甜瓜'},
#  '⚲': {'中性'},
#  '🧓': {'老年人'},
#  '🌳': {'落叶树'},
#  '🦜': {'鹦鹉'},
#  '😕': {'困扰'},
#  '🐁': {'老鼠'},
#  '🧜': {'人鱼'},
#  '❤': {'红心'},
#  '👏': {'鼓掌'},
#  '🏇': {'赛马'},
#  '🧭': {'指南针'},
#  '🏑': {'曲棍球'},
#  '🧠': {'脑'},
#  '🧜\u200d♀️': {'美人鱼'},
#  '🐜': {'蚂蚁'},
#  '♆': {'海王星'},
#  '🧥': {'外套'},
#  '👸': {'公主'},
#  '🎢': {'过山车'},
#  '⛆': {'雨'},
#  '🚢': {'船'},
#  '🎲': {'骰子'},
#  '👙': {'比基尼'},
#  '🦘': {'袋鼠'},
#  '♨': {'温泉'},
#  '🏡': {'别墅'},
#  '😭': {'放声大哭'},
#  '☹': {'不满'},
#  '🌫': {'雾'},
#  '🤖': {'机器人'},
#  '💻': {'笔记本电脑'},
#  '🦆': {'鸭子'},
#  '🏭': {'工厂'},
#  '😶': {'沉默'},
#  '♩': {'四分音符'},
#  '👮': {'警察'},
#  '🚆': {'火车'},
#  '😣': {'痛苦'},
#  '🥴': {'头昏眼花'},
#  '🌿': {'药草'},
#  '⛺': {'帐篷'},
#  '😀': {'嘿嘿'},
#  '💇': {'理发'},
#  '🐙': {'章鱼'},
#  '☎': {'电话'},
#  '🐊': {'鳄鱼'},
#  '🔥': {'火焰'},
#  '🧢': {'鸭舌帽'},
#  '👋': {'挥手'},
#  '💰': {'钱袋'},
#  '🖤': {'黑心'},
#  '🎸': {'吉他'},
#  '🐠': {'热带鱼'},
#  '🕶': {'墨镜'},
#  '🦲': {'秃顶'},
#  '📹': {'摄像机'},
#  '🎟': {'入场券'},
#  '🥕': {'胡萝卜'},
#  '⛰': {'山'},
#  '🦋': {'蝴蝶'},
#  '🏬': {'商场'},
#  '🐕': {'狗'},
#  '😰': {'冷汗'},
#  '🍒': {'樱桃'},
#  '⛵': {'帆船'},
#  '🧳': {'行李箱'},
#  '👄': {'嘴'},
#  '🌹': {'玫瑰'},
#  '🌾': {'稻子'},
#  '⭐': {'星星'},
#  '🤽': {'水球'},
#  '📽': {'电影放映机'},
#  '💒': {'婚礼'},
#  '💷': {'英镑'},
#  '🍥': {'鱼板'},
#  '♄': {'土星'},
#  '🏸': {'羽毛球'},
#  '🍬': {'糖'},
#  '🌲': {'松树'},
#  '🧙': {'法师'},
#  '✍': {'写字'},
#  '🥒': {'黄瓜'},
#  '🙍': {'皱眉'},
#  '💿': {'光盘'},
#  '🌼': {'开花'},
#  '🎾': {'网球'},
#  '🥥': {'椰子'},
#  '🦎': {'蜥蜴'},
#  '👖': {'牛仔裤'},
#  '👨\u200d🌾': {'农夫'},
#  '🦍': {'大猩猩'},
#  '🗽': {'自由女神像'},
#  '🖍': {'蜡笔'},
#  '🥰': {'喜笑颜开'},
#  '🦡': {'獾'},
#  '🌅': {'日出'},
#  '💁': {'前台'},
#  '💧': {'水滴'},
#  '😅': {'苦笑'},
#  '🌷': {'郁金香'},
#  '🍻': {'干杯'},
#  '🍖': {'排骨'},
#  '✉': {'信封'},
#  '🥉': {'铜牌'},
#  '🦛': {'河马'},
#  '🍷': {'葡萄酒'},
#  '🍞': {'面包'},
#  '🥞': {'烙饼'},
#  '💑': {'情侣'},
#  '🐈': {'猫'},
#  '📠': {'传真机'},
#  '✨': {'闪亮'},
#  '🍽': {'餐具'},
#  '😫': {'累'},
#  '🦱': {'卷发'},
#  '🥧': {'派'},
#  '🐤': {'小鸡'},
#  '🍯': {'蜂蜜'},
#  '🐲': {'龙头'},
#  '💤': {'睡着'},
#  '⛱': {'阳伞'},
#  '🦀': {'蟹'},
#  '🏅': {'奖牌'},
#  '📮': {'邮筒'},
#  '🎈': {'气球'},
#  '🛷': {'雪橇'},
#  '🍼': {'奶瓶'},
#  '⚘': {'花'},
#  '👠': {'高跟鞋'},
#  '🤪': {'滑稽'},
#  '🏚': {'废墟'},
#  '🍉': {'西瓜'},
#  '🏞': {'国家公园'},
#  '🍩': {'甜甜圈'},
#  '📿': {'念珠'},
#  '🍐': {'梨'},
#  '🐧': {'企鹅'},
#  '🧝': {'小精灵'},
#  '⛫': {'城堡'},
#  '🎄': {'圣诞树'},
#  '🏠': {'房子'},
#  '🦟': {'蚊子'},
#  '🚑': {'救护车'},
#  '👟': {'跑鞋'},
#  '♇': {'冥王星'},
#  '🕊': {'鸽'},
#  '👩': {'女人'},
#  '🛏': {'床'},
#  '☔': {'雨伞'},
#  '🚁': {'直升机'},
#  '♅': {'天王星'},
#  '🥭': {'芒果'},
#  '💆': {'按摩'},
#  '\U0001fa81': {'风筝'},
#  '💵': {'美元'},
#  '🧦': {'袜子'},
#  '📚': {'书'},
#  '😒': {'不高兴'},
#  '👃': {'鼻子'},
#  '🦁': {'狮子'},
#  '😪': {'困'},
#  '💔': {'心碎'},
#  '🏕': {'露营'},
#  '📦': {'包裹'},
#  '🍌': {'香蕉'},
#  '🍑': {'桃'},
#  '👺': {'小妖精'},
#  '🐀': {'耗子'},
#  '🍄': {'蘑菇'},
#  '☠': {'骷髅'},
#  '🦃': {'火鸡'},
#  '🎱': {'台球'},
#  '🌻': {'向日葵'},
#  '🍫': {'巧克力'},
#  '👽': {'外星人'},
#  '🦶': {'脚'},
#  '🐏': {'公羊'},
#  '🌭': {'热狗'},
#  '🥿': {'平底鞋'},
#  '🐔': {'鸡'},
#  '🌬': {'大风'},
#  '🏋': {'举重'},
#  '🚜': {'拖拉机'},
#  '💫': {'头晕'},
#  '🚠': {'缆车'},
#  '😵': {'晕头转向'},
#  '🔔': {'铃铛'},
#  '🐒': {'猴子'},
#  '🤢': {'恶心'},
#  '☺': {'微笑'},
#  '🌘': {'残月'},
#  '👤': {'人像'},
#  '⚓': {'锚'},
#  '♁': {'地球'},
#  '👴': {'老爷爷'},
#  '🚗': {'汽车'},
#  '🧾': {'收据'},
#  '🚀': {'火箭'},
#  '\U0001f9a5': {'树懒'},
#  '🐐': {'山羊'},
#  '🤒': {'发烧'},
#  '🥎': {'垒球'},
#  '💋': {'唇印'},
#  '\U0001f971': {'打呵欠'},
#  '🗈': {'内容'},
#  '🀄': {'红中'},
#  '🎀': {'蝴蝶结'},
#  '💯': {'一百分'},
#  '🐦': {'鸟'},
#  '😉': {'眨眼'},
#  '😄': {'大笑'},
#  '🌀': {'台风'},
#  '😐': {'冷漠'},
#  '🎵': {'音符'},
#  '😯': {'缄默'},
#  '💂': {'卫兵'},
#  '🦝': {'浣熊'},
#  '🦚': {'孔雀'},
#  '🐗': {'野猪'},
#  '\U0001f9aa': {'牡蛎'},
#  '🗢': {'嘴唇'},
#  '🖴': {'硬盘'},
#  '🍆': {'茄子'},
#  '🌸': {'樱花'},
#  '🥟': {'饺子'},
#  '🗣': {'说话'},
#  '⛴': {'渡轮'},
#  '🐿': {'松鼠'},
#  '😟': {'担心'},
#  '🧚': {'精灵'},
#  '🎼': {'乐谱'},
#  '😮': {'吃惊'},
#  '🔦': {'手电筒'},
#  '🧒': {'儿童'},
#  '🤕': {'受伤'},
#  '🐢': {'龟'}}

# %%
emoji_dict=emoji_list

# %%
emoji_file='senti_dict/emoji_dict/emoji.txt'

# %%
with open(emoji_file,'a',encoding='utf-8') as f:
    for k,v in emoji_dict.items():
        f.write(str(k)+' '+str(v)+'\n')
